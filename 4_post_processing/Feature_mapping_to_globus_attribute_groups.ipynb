# %%
from datetime import datetime
import pandas as pd
import numpy as np
from pathlib import Path  # for OS-safe path handling
import os
from ast import literal_eval
from sklearn.preprocessing import MultiLabelBinarizer
import pickle

# %% [markdown]
# # Load the raw metadata

# %%
#Globus path:
#path_pickle = Path('data') / '../1_cleaning/parsed_records_dump_20200103.p'

path_pickle = '../../efs/parsed_records_dump_20200103.p'
parsed_records = pickle.load(open(path_pickle, 'rb'))

# %%
meta_data_columns = [
    'globus_id',
    'descr',
    'name',
    'gender',
    'source_color',
    'color',
    'url',
    'material',
    'features',
    'season',
    'hierarchy_full',
    #     'hierarchy_1','hierarchy_2', 'hierarchy_3', 'hierarchy_4', 'hierarchy_5', 'hierarchy_6',
    'href',
    'prod_id'
]

# %%
df_metadata = pd.DataFrame(parsed_records, columns=meta_data_columns)

# %%
df_metadata[['name','features', 'hierarchy_full']]
# Out:
#                                                   name  \
# 0                                                Globi
# 1                                                Globi
# 2                                          H&H No Name
# 3                                     Diorshow Mascara
# 4                                                Globi
# 5                            Redwood Creek Chardonnay
# 6                           Redwood Creek, Merlot 2012
# 7                                      Powercell Serum
# 8                         Ersatz-Toilettenbürstenkopf
# 9                                      Powercell Serum
# 10                     Powercell Masque\nGesichtsmaske
# 11                                     Powercell Crème
# 12                   Powercell Crème Yeux\nAugenpflege
# 13                                 Zahnbürstenbehälter
# 14                                            Behälter
# 15                                    Seifenschale aus
# 16                                       Seifenspender
# 17                                 Flor de Pingus 2011
# 18                                 Bioeffect EGF Serum
# 19                                    30 Day Treatment
# 20                                          Demi Glace
# 21                                       EGF Eye Serum
# 22                                     Glace de viande
# 23                                      Body Intensive
# 24                               Kartoffelstampfgewürz
# 25                 Moulin de la Lagune Haut-Médoc 2011
# 26                           Diorissimo Extrait Flacon
# 27                                     J'Adore Extrait
# 28                                           Miss Dior
# 29                                   Eiswürfelbehälter
# ...                                                ...
# 217103           Sardines in Olive Oil Millésimés 2016
# 217104  Il Vino dell'Amore Petalo Manzoni Moscato Rosé
# 217105                              Tuiles mit Mandeln
# 217106                    Nori getrocknete Meeresalgen
# 217107                      Marshmallow Stick 3 Herzen
# 217108                                    Mallow Stick
# 217109                    Instant Noodles Miso Flavour
# 217110                    Instant Noodles Miso Flavour
# 217111                    Instant Noodles Miso Flavour
# 217112                                      Dijon-Senf
# 217113                                Dragées al Latte
# 217114                                Dragées al Latte
# 217115                                     Tonic Water
# 217116                                 Pomodori Pelati
# 217117                             Pfefferschotensauce
# 217118                    Japanischer Meergemüse-Salat
# 217119          325th Anniversary Limited Edition Port
# 217120                                      Palmherzen
# 217121                                 Tomaten gehackt
# 217122                   Pistazien mit Milchschokolade
# 217123              Basis für asiatische Suppe Tom Yam
# 217124                      Makrelenfilet in Weisswein
# 217125                                  Crema Piccante
# 217126     10 Years Old Single Malt Scotch Whisky Mini
# 217127                                Trocla Nera 2014
# 217128                                Trocla Nera 2014
# 217129                         Mayonnaise mit Olivenöl
# 217130                         Mayonnaise mit Olivenöl
# 217131                                        Spice 94
# 217132                                      Garden 108
#
#                                                  features  \
# 0       [globus:pim.heimhaushalt.sprache-deutsch, glob...
# 1       [globus:pim.heimhaushalt.sprache-deutsch, glob...
# 2       [globus:pim.heimhaushalt.sprache-deutsch, glob...
# 3       [globus:pim.beauty.naturkosmetik-False, globus...
# 4       [globus:pim.heimhaushalt.sprache-deutsch, glob...
# 5       [globus:pim.general.ursprungsland-US, globus:p...
# 6       [globus:pim.general.ursprungsland-US, globus:p...
# 7       [globus:pim.beauty.naturkosmetik-False, globus...
# 8       [globus:pim.general.produktbeschreibungextern-...
# 9       [globus:pim.beauty.naturkosmetik-False, globus...
# 10      [globus:pim.beauty.naturkosmetik-False, globus...
# 11      [globus:pim.beauty.naturkosmetik-False, globus...
# 12      [globus:pim.beauty.naturkosmetik-False, globus...
# 13      [globus:pim.general.produktbeschreibungextern-...
# 14      [globus:pim.general.produktbeschreibungextern-...
# 15      [globus:pim.general.produktbeschreibungextern-...
# 16      [globus:pim.general.produktbeschreibungextern-...
# 17      [globus:pim.delicatessa.alkoholgehalt-liste-15...
# 18      [globus:pim.beauty.naturkosmetik-False, globus...
# 19      [globus:pim.beauty.naturkosmetik-False, globus...
# 20      [globus:pim.delicatessa.superfood-False, globu...
# 21      [globus:pim.beauty.naturkosmetik-False, globus...
# 22      [globus:pim.delicatessa.superfood-False, globu...
# 23      [globus:pim.beauty.naturkosmetik-False, globus...
# 24      [globus:pim.delicatessa.superfood-False, globu...
# 25      [globus:pim.blockgalaxusoutput-True, globus:pi...
# 26      [globus:pim.beauty.naturkosmetik-False, globus...
# 27      [globus:pim.beauty.naturkosmetik-False, globus...
# 28      [globus:pim.beauty.naturkosmetik-False, globus...
# 29                                                     []
# ...                                                   ...
# 217103  [globus:pim.delicatessa.superfood-False, globu...
# 217104  [globus:pim.delicatessa.wein.aromenfilter2-Zit...
# 217105  [globus:pim.delicatessa.superfood-False, globu...
# 217106  [globus:pim.delicatessa.superfood-False, globu...
# 217107  [globus:pim.delicatessa.superfood-False, globu...
# 217108  [globus:pim.delicatessa.superfood-False, globu...
# 217109  [globus:pim.delicatessa.superfood-False, globu...
# 217110  [globus:pim.delicatessa.superfood-False, globu...
# 217111  [globus:pim.delicatessa.superfood-False, globu...
# 217112  [globus:pim.delicatessa.superfood-False, globu...
# 217113  [globus:pim.delicatessa.superfood-False, globu...
# 217114  [globus:pim.delicatessa.superfood-False, globu...
# 217115  [globus:pim.delicatessa.verpackung-Flasche, gl...
# 217116  [globus:pim.delicatessa.superfood-False, globu...
# 217117  [globus:pim.delicatessa.superfood-False, globu...
# 217118  [globus:pim.delicatessa.superfood-False, globu...
# 217119  [globus:pim.delicatessa.wein.aromenfilter2-Sch...
# 217120  [globus:pim.delicatessa.superfood-False, globu...
# 217121  [globus:pim.delicatessa.superfood-False, globu...
# 217122  [globus:pim.delicatessa.superfood-False, globu...
# 217123  [globus:pim.delicatessa.superfood-False, globu...
# 217124  [globus:pim.delicatessa.superfood-False, globu...
# 217125  [globus:pim.delicatessa.superfood-False, globu...
# 217126  [globus:pim.delicatessa.produzentmarkespirituo...
# 217127  [globus:pim.delicatessa.wein.aromenfilter2-Eic...
# 217128  [globus:pim.delicatessa.wein.aromenfilter2-Eic...
# 217129  [globus:pim.delicatessa.superfood-False, globu...
# 217130  [globus:pim.delicatessa.superfood-False, globu...
# 217131  [globus:pim.delicatessa.produzentmarkespirituo...
# 217132  [globus:pim.delicatessa.produzentmarkespirituo...
#
#                                            hierarchy_full
# 0          globus:pim.category.kinder.spielwarencdbuecher
# 1          globus:pim.category.kinder.spielwarencdbuecher
# 2          globus:pim.category.kinder.spielwarencdbuecher
# 3                      globus:pim.category.beauty.make-up
# 4          globus:pim.category.kinder.spielwarencdbuecher
# 5          globus:pim.category.delicatessa.getranke.weine
# 6          globus:pim.category.delicatessa.getranke.weine
# 7                       globus:pim.category.beauty.pflege
# 8       globus:pim.category.heim-haushalt.bad.badacces...
# 9                       globus:pim.category.beauty.pflege
# 10                      globus:pim.category.beauty.pflege
# 11                      globus:pim.category.beauty.pflege
# 12                      globus:pim.category.beauty.pflege
# 13      globus:pim.category.heim-haushalt.bad.badacces...
# 14      globus:pim.category.heim-haushalt.bad.badaufbe...
# 15      globus:pim.category.heim-haushalt.bad.badacces...
# 16      globus:pim.category.heim-haushalt.bad.badaufbe...
# 17         globus:pim.category.delicatessa.getranke.weine
# 18                      globus:pim.category.beauty.pflege
# 19                      globus:pim.category.beauty.pflege
# 20      globus:pim.category.delicatessa.saucen-suppen....
# 21                      globus:pim.category.beauty.pflege
# 22      globus:pim.category.delicatessa.saucen-suppen....
# 23                      globus:pim.category.beauty.pflege
# 24        globus:pim.category.delicatessa.gewurze.gewurze
# 25         globus:pim.category.delicatessa.getranke.weine
# 26                        globus:pim.category.beauty.duft
# 27                        globus:pim.category.beauty.duft
# 28                        globus:pim.category.beauty.duft
# 29      globus:pim.category.heim-haushalt.kuche.kuchen...
# ...                                                   ...
# 217103  globus:pim.category.delicatessa.fische-meeresf...
# 217104     globus:pim.category.delicatessa.getranke.weine
# 217105  globus:pim.category.delicatessa.schokolade-sus...
# 217106              globus:pim.category.delicatessa.ethno
# 217107  globus:pim.category.delicatessa.schokolade-sus...
# 217108  globus:pim.category.delicatessa.schokolade-sus...
# 217109              globus:pim.category.delicatessa.ethno
# 217110              globus:pim.category.delicatessa.ethno
# 217111              globus:pim.category.delicatessa.ethno
# 217112  globus:pim.category.delicatessa.saucen-suppen....
# 217113  globus:pim.category.delicatessa.schokolade-sus...
# 217114  globus:pim.category.delicatessa.schokolade-sus...
# 217115  globus:pim.category.delicatessa.getranke.erfri...
# 217116  globus:pim.category.delicatessa.gemuse.gemusek...
# 217117  globus:pim.category.delicatessa.saucen-suppen....
# 217118              globus:pim.category.delicatessa.ethno
# 217119  globus:pim.category.delicatessa.getranke.sherr...
# 217120  globus:pim.category.delicatessa.gemuse.gemusek...
# 217121  globus:pim.category.delicatessa.gemuse.gemusek...
# 217122  globus:pim.category.delicatessa.schokolade-sus...
# 217123              globus:pim.category.delicatessa.ethno
# 217124  globus:pim.category.delicatessa.fische-meeresf...
# 217125  globus:pim.category.delicatessa.saucen-suppen....
# 217126  globus:pim.category.delicatessa.getranke.spiri...
# 217127     globus:pim.category.delicatessa.getranke.weine
# 217128     globus:pim.category.delicatessa.getranke.weine
# 217129  globus:pim.category.delicatessa.saucen-suppen....
# 217130  globus:pim.category.delicatessa.saucen-suppen....
# 217131  globus:pim.category.delicatessa.getranke.spiri...
# 217132  globus:pim.category.delicatessa.getranke.spiri...
#
# [217133 rows x 3 columns]

# %%
def split_hierarchy(x):
    try:
        return (pd.Series(x.split('.')))[3:4]
    except:
        return ''

dfx = df_metadata['hierarchy_full'].head(10).apply(split_hierarchy)
                                             

# hierarchy_columns = [
#     f'hierarchy_{col+1}' for col in range(len(df_tmp.columns))
# ]
# df_metadata[hierarchy_columns] = df_tmp

# %%
df_metadata.dropna(subset=['url'], inplace=True)
df_metadata.dropna(subset=['features'], inplace=True)
df_metadata.dropna(subset=['hierarchy_full'], inplace=True)
df_metadata.dropna(subset=['descr'], inplace=True)
df_metadata.dropna(subset=['source_color'], inplace=True)

# %% [markdown]
# ## Get only Fashion Entries

# %%
categories_fashion = [
    'taschen', 'schuhe', 'pullover-strick', 'top-shirts-sweats', 'schals',
    'hemden', 'hosen', 'oberteile', 'blusen-tuniken', 'shirts-tops-sweats',
    'kleider'
]

# %%
df_tmp = df_metadata['hierarchy_full'].apply(lambda x:
                                             (pd.Series(x.split('.')))[2:])

hierarchy_columns = [
    f'hierarchy_{col+1}' for col in range(len(df_tmp.columns))
]
df_metadata[hierarchy_columns] = df_tmp

# %%
df_metadata[df_metadata['hierarchy_2'].isin( categories_fashion)]
# Out:
#         globus_id             descr                  name  gender  \
# 35        26653.0     umhangetasche  MICHAEL MICHAEL KORS   damen
# 36        26663.0     umhangetasche  MICHAEL MICHAEL KORS   damen
# 37        26665.0     umhangetasche  MICHAEL MICHAEL KORS   damen
# 38        26655.0     umhangetasche  MICHAEL MICHAEL KORS   damen
# 39        38482.0     umhangetasche  MICHAEL MICHAEL KORS   damen
# 40        46584.0     umhangetasche  MICHAEL MICHAEL KORS   damen
# 46        26647.0     umhangetasche  MICHAEL MICHAEL KORS   damen
# 71       322479.0      winterschuhe                   UGG  kinder
# 84        36001.0    hemdregularfit        TOMMY HILFIGER  herren
# 112       36113.0         chinohose        TOMMY HILFIGER  herren
# 114       36093.0         chinohose        TOMMY HILFIGER  herren
# 118       36089.0         chinohose        TOMMY HILFIGER  herren
# 311      324059.0        handtasche   LAUREN RALPH LAUREN   damen
# 319      324071.0        handtasche   LAUREN RALPH LAUREN   damen
# 320      450926.0        handtasche   LAUREN RALPH LAUREN   damen
# 321      450928.0        handtasche   LAUREN RALPH LAUREN   damen
# 322      476176.0        handtasche   LAUREN RALPH LAUREN   damen
# 323      476178.0        handtasche   LAUREN RALPH LAUREN   damen
# 324      450930.0        handtasche   LAUREN RALPH LAUREN   damen
# 325       36314.0        handtasche   LAUREN RALPH LAUREN   damen
# 326      476180.0        handtasche   LAUREN RALPH LAUREN   damen
# 327     1244593.0        handtasche   LAUREN RALPH LAUREN   damen
# 328       38945.0        handtasche   LAUREN RALPH LAUREN   damen
# 329      450922.0        handtasche   LAUREN RALPH LAUREN   damen
# 354       32910.0    hemdregularfit             NAPAPIJRI  herren
# 355       32928.0    hemdregularfit             NAPAPIJRI  herren
# 358       32906.0       hemdslimfit             NAPAPIJRI  herren
# 359       32914.0       hemdslimfit             NAPAPIJRI  herren
# 393       26768.0  cashmerepullover     GLOBUS ESSENTIALS   damen
# 394       26724.0  cashmerepullover     GLOBUS ESSENTIALS   damen
# ...           ...               ...                   ...     ...
# 204092  2083649.0       hemdslimfit             STRELLSON  herren
# 204093  2083639.0       hemdslimfit             STRELLSON  herren
# 204094  2083624.0       hemdslimfit             STRELLSON  herren
# 204095  2083644.0       hemdslimfit             STRELLSON  herren
# 204096  2083619.0       hemdslimfit             STRELLSON  herren
# 204105  2076294.0       hemdslimfit                  ETON  herren
# 205978  2079919.0      langarmshirt             HALLHUBER   damen
# 205982  2090917.0      schlupfbluse       CLAUDIE PIERLOT   damen
# 205984  2090927.0      schlupfbluse       CLAUDIE PIERLOT   damen
# 206246  2074250.0       jerseykleid                  OPUS   damen
# 206251  2074245.0      langarmshirt               SOMEDAY   damen
# 206281  2074240.0      langarmshirt                  OPUS   damen
# 206787  2074231.0         stoffhose                  OPUS   damen
# 206805  2085094.0    strickpullover               SOMEDAY   damen
# 206814  2079914.0         stoffhose               SOMEDAY   damen
# 210058  2083629.0       hemdslimfit                  ETON  herren
# 210454  2079687.0     umhangetasche      ZADIG & VOLTAIRE   damen
# 210533  2083653.0           sneaker                Adidas  herren
# 211313  2080021.0    strickpullover                SANDRO   damen
# 211327  2080012.0    strickpullover                SANDRO   damen
# 211328  2080031.0    strickpullover                SANDRO   damen
# 211329  2080041.0       strickkleid                SANDRO   damen
# 211330  2080026.0    strickpullover                SANDRO   damen
# 211333  2080051.0             kleid                SANDRO   damen
# 211334  2080046.0             kleid                SANDRO   damen
# 211335  2080036.0         longbluse                SANDRO   damen
# 211519  2090890.0             kleid                SANDRO   damen
# 211520  2090880.0             kleid                SANDRO   damen
# 211545  2090904.0      schlupfbluse                SANDRO   damen
# 211553  2090936.0      schlupfbluse                SANDRO   damen
#
#        source_color                     color  \
# 35             blau                      navy
# 36          schwarz                   schwarz
# 37            braun                     braun
# 38             grün                      grün
# 39             grün                  hellgrün
# 40            weiss                     weiss
# 46            beige                      sand
# 71            weiss                      ecru
# 84             blau                      navy
# 112             rot                  bordeaux
# 114            blau                      navy
# 118           braun                     braun
# 311         schwarz                   schwarz
# 319            grau                  hellgrau
# 320             rot                       rot
# 321           braun                     camel
# 322           beige                      sand
# 323             rot                 carminrot
# 324           braun                     camel
# 325           braun                     taupe
# 326           beige                      sand
# 327           beige                 hellbeige
# 328           braun                     taupe
# 329           braun                     camel
# 354             rot               rot kariert
# 355            blau              blau kariert
# 358            blau            ciel gestreift
# 359            blau            blau gestreift
# 393             rot                  bordeaux
# 394            grau                  hellgrau
# ...             ...                       ...
# 204092         blau                  hellblau
# 204093         blau                      navy
# 204094         blau  hellblau/klein gemustert
# 204095         blau        hellblau gestreift
# 204096         blau      navy/klein gemustert
# 204105        weiss                     weiss
# 205978      schwarz                   schwarz
# 205982        weiss                     perle
# 205984         blau                    marine
# 206246      schwarz                   schwarz
# 206251         blau                      blau
# 206281         blau                     royal
# 206787         blau                 nachtblau
# 206805        weiss                  offwhite
# 206814        braun                     camel
# 210058        weiss     weiss/klein gemustert
# 210454         grün                     khaki
# 210533      schwarz                   schwarz
# 211313         blau                    marine
# 211327         blau                    marine
# 211328         grün                   smaragd
# 211329         blau                    marine
# 211330         blau                    marine
# 211333      schwarz                   schwarz
# 211334      schwarz                   schwarz
# 211335       silber              silberfarben
# 211519      schwarz                   schwarz
# 211520         blau                    marine
# 211545         blau                      ciel
# 211553         blau                    marine
#
#                                                       url  \
# 35      https://apitest.censhare.globus.ch/image/26653...
# 36      https://apitest.censhare.globus.ch/image/26663...
# 37      https://apitest.censhare.globus.ch/image/26665...
# 38      https://apitest.censhare.globus.ch/image/26655...
# 39      https://apitest.censhare.globus.ch/image/38482...
# 40      https://apitest.censhare.globus.ch/image/46584...
# 46      https://apitest.censhare.globus.ch/image/26647...
# 71      https://apitest.censhare.globus.ch/image/32247...
# 84      https://apitest.censhare.globus.ch/image/36001...
# 112     https://apitest.censhare.globus.ch/image/36113...
# 114     https://apitest.censhare.globus.ch/image/36093...
# 118     https://apitest.censhare.globus.ch/image/36089...
# 311     https://apitest.censhare.globus.ch/image/32405...
# 319     https://apitest.censhare.globus.ch/image/32407...
# 320     https://apitest.censhare.globus.ch/image/45092...
# 321     https://apitest.censhare.globus.ch/image/45092...
# 322     https://apitest.censhare.globus.ch/image/47617...
# 323     https://apitest.censhare.globus.ch/image/47617...
# 324     https://apitest.censhare.globus.ch/image/45093...
# 325     https://apitest.censhare.globus.ch/image/36314...
# 326     https://apitest.censhare.globus.ch/image/47618...
# 327     https://apitest.censhare.globus.ch/image/12445...
# 328     https://apitest.censhare.globus.ch/image/38945...
# 329     https://apitest.censhare.globus.ch/image/45092...
# 354     https://apitest.censhare.globus.ch/image/32910...
# 355     https://apitest.censhare.globus.ch/image/32928...
# 358     https://apitest.censhare.globus.ch/image/32906...
# 359     https://apitest.censhare.globus.ch/image/32914...
# 393     https://apitest.censhare.globus.ch/image/26768...
# 394     https://apitest.censhare.globus.ch/image/26724...
# ...                                                   ...
# 204092  https://apitest.censhare.globus.ch/image/20836...
# 204093  https://apitest.censhare.globus.ch/image/20836...
# 204094  https://apitest.censhare.globus.ch/image/20836...
# 204095  https://apitest.censhare.globus.ch/image/20836...
# 204096  https://apitest.censhare.globus.ch/image/20836...
# 204105  https://apitest.censhare.globus.ch/image/20762...
# 205978  https://apitest.censhare.globus.ch/image/20799...
# 205982  https://apitest.censhare.globus.ch/image/20909...
# 205984  https://apitest.censhare.globus.ch/image/20909...
# 206246  https://apitest.censhare.globus.ch/image/20742...
# 206251  https://apitest.censhare.globus.ch/image/20742...
# 206281  https://apitest.censhare.globus.ch/image/20742...
# 206787  https://apitest.censhare.globus.ch/image/20742...
# 206805  https://apitest.censhare.globus.ch/image/20850...
# 206814  https://apitest.censhare.globus.ch/image/20799...
# 210058  https://apitest.censhare.globus.ch/image/20836...
# 210454  https://apitest.censhare.globus.ch/image/20796...
# 210533  https://apitest.censhare.globus.ch/image/20836...
# 211313  https://apitest.censhare.globus.ch/image/20800...
# 211327  https://apitest.censhare.globus.ch/image/20800...
# 211328  https://apitest.censhare.globus.ch/image/20800...
# 211329  https://apitest.censhare.globus.ch/image/20800...
# 211330  https://apitest.censhare.globus.ch/image/20800...
# 211333  https://apitest.censhare.globus.ch/image/20800...
# 211334  https://apitest.censhare.globus.ch/image/20800...
# 211335  https://apitest.censhare.globus.ch/image/20800...
# 211519  https://apitest.censhare.globus.ch/image/20908...
# 211520  https://apitest.censhare.globus.ch/image/20908...
# 211545  https://apitest.censhare.globus.ch/image/20909...
# 211553  https://apitest.censhare.globus.ch/image/20909...
#
#                                                  material  \
# 35                       [globus:pim.general.material-L1]
# 36                       [globus:pim.general.material-L1]
# 37                       [globus:pim.general.material-L1]
# 38                       [globus:pim.general.material-L1]
# 39                       [globus:pim.general.material-L1]
# 40                       [globus:pim.general.material-L1]
# 46                       [globus:pim.general.material-L1]
# 71                      [globus:pim.general.material-L10]
# 84                       [globus:pim.general.material-CO]
# 112     [globus:pim.general.material-CO, globus:pim.ge...
# 114     [globus:pim.general.material-CO, globus:pim.ge...
# 118     [globus:pim.general.material-CO, globus:pim.ge...
# 311                      [globus:pim.general.material-L1]
# 319                      [globus:pim.general.material-L1]
# 320                      [globus:pim.general.material-L1]
# 321                      [globus:pim.general.material-L1]
# 322                      [globus:pim.general.material-L1]
# 323                      [globus:pim.general.material-L1]
# 324                      [globus:pim.general.material-L2]
# 325                      [globus:pim.general.material-L2]
# 326                      [globus:pim.general.material-L2]
# 327                      [globus:pim.general.material-L2]
# 328                      [globus:pim.general.material-L1]
# 329                      [globus:pim.general.material-L1]
# 354                      [globus:pim.general.material-CO]
# 355                      [globus:pim.general.material-CO]
# 358     [globus:pim.general.material-CO, globus:pim.ge...
# 359     [globus:pim.general.material-CO, globus:pim.ge...
# 393                     [globus:pim.general.material-CAC]
# 394                     [globus:pim.general.material-CAC]
# ...                                                   ...
# 204092                   [globus:pim.general.material-CO]
# 204093                   [globus:pim.general.material-CO]
# 204094                   [globus:pim.general.material-CO]
# 204095                   [globus:pim.general.material-CO]
# 204096                   [globus:pim.general.material-CO]
# 204105                   [globus:pim.general.material-CO]
# 205978  [globus:pim.general.material-CV, globus:pim.ge...
# 205982  [globus:pim.general.material-CTA, globus:pim.g...
# 205984                  [globus:pim.general.material-PES]
# 206246  [globus:pim.general.material-CV, globus:pim.ge...
# 206251  [globus:pim.general.material-CV, globus:pim.ge...
# 206281  [globus:pim.general.material-CV, globus:pim.ge...
# 206787  [globus:pim.general.material-CO, globus:pim.ge...
# 206805                   [globus:pim.general.material-CO]
# 206814  [globus:pim.general.material-PES, globus:pim.g...
# 210058                   [globus:pim.general.material-CO]
# 210454           [globus:pim.general.material-pim-textil]
# 210533     [globus:pim.general.futtermaterial-pim-textil]
# 211313  [globus:pim.general.material-WO, globus:pim.ge...
# 211327  [globus:pim.general.material-WO, globus:pim.ge...
# 211328  [globus:pim.general.material-CV, globus:pim.ge...
# 211329  [globus:pim.general.material-CV, globus:pim.ge...
# 211330  [globus:pim.general.material-CO, globus:pim.ge...
# 211333                   [globus:pim.general.material-CV]
# 211334                  [globus:pim.general.material-PES]
# 211335                   [globus:pim.general.material-CV]
# 211519            [globus:pim.general.futtermaterial-PES]
# 211520            [globus:pim.general.futtermaterial-PES]
# 211545                   [globus:pim.general.material-CV]
# 211553                   [globus:pim.general.material-CO]
#
#                                                  features season  \
# 35      [globus:pim.accessoires.navdamentaschen-umhang...      B
# 36      [globus:pim.accessoires.navdamentaschen-umhang...      B
# 37      [globus:pim.accessoires.navdamentaschen-umhang...      B
# 38      [globus:pim.accessoires.navdamentaschen-umhang...      B
# 39      [globus:pim.accessoires.navdamentaschen-umhang...      B
# 40      [globus:pim.accessoires.navdamentaschen-umhang...      B
# 46      [globus:pim.accessoires.navdamentaschen-umhang...      B
# 71      [globus:pim.accessoires.decksohle-textil, glob...      W
# 84      [globus:pim.general.passform-001, globus:pim.g...      W
# 112     [globus:pim.general.pflegehinweis.waschen-4, g...      W
# 114     [globus:pim.general.pflegehinweis.waschen-4, g...      W
# 118     [globus:pim.general.pflegehinweis.waschen-4, g...      W
# 311     [globus:pim.accessoires.navdamentaschen-handta...      S
# 319     [globus:pim.accessoires.navdamentaschen-handta...      S
# 320     [globus:pim.accessoires.navdamentaschen-handta...      S
# 321     [globus:pim.accessoires.navdamentaschen-handta...      S
# 322     [globus:pim.accessoires.navdamentaschen-handta...      S
# 323     [globus:pim.accessoires.navdamentaschen-handta...      S
# 324     [globus:pim.accessoires.navdamentaschen-handta...      S
# 325     [globus:pim.accessoires.navdamentaschen-handta...      S
# 326     [globus:pim.accessoires.navdamentaschen-handta...      S
# 327     [globus:pim.accessoires.navdamentaschen-handta...      S
# 328     [globus:pim.accessoires.navdamentaschen-handta...      S
# 329     [globus:pim.accessoires.navdamentaschen-handta...      S
# 354     [globus:pim.general.passform-001, globus:pim.g...      W
# 355     [globus:pim.general.passform-001, globus:pim.g...      W
# 358     [globus:pim.general.passform-002, globus:pim.g...      W
# 359     [globus:pim.general.passform-002, globus:pim.g...      W
# 393     [globus:pim.general.pflegehinweis.waschen-1, g...      W
# 394     [globus:pim.general.pflegehinweis.waschen-1, g...      W
# ...                                                   ...    ...
# 204092  [globus:pim.general.passform-002, globus:pim.g...      S
# 204093  [globus:pim.general.passform-002, globus:pim.g...      S
# 204094  [globus:pim.general.passform-002, globus:pim.g...      S
# 204095  [globus:pim.general.passform-002, globus:pim.g...      S
# 204096  [globus:pim.general.passform-002, globus:pim.g...      S
# 204105  [globus:pim.general.passform-002, globus:pim.g...      S
# 205978  [globus:pim.general.pflegehinweis.waschen-1, g...      N
# 205982  [globus:pim.general.pflegehinweis.waschen-F, g...      N
# 205984  [globus:pim.general.pflegehinweis.waschen-1, g...      N
# 206246  [globus:pim.damenfashion.rocklange-inmidirockl...      N
# 206251  [globus:pim.general.pflegehinweis.waschen-F, g...      N
# 206281  [globus:pim.general.pflegehinweis.waschen-F, g...      N
# 206787  [globus:pim.general.pflegehinweis.waschen-F, g...      N
# 206805  [globus:pim.general.pflegehinweis.waschen-F, g...      N
# 206814  [globus:pim.general.pflegehinweis.waschen-F, g...      N
# 210058  [globus:pim.general.passform-002, globus:pim.g...      S
# 210454  [globus:pim.accessoires.navdamentaschen-umhang...      N
# 210533  [globus:pim.accessoires.decksohle-leder, globu...      S
# 211313  [globus:pim.general.pflegehinweis.waschen-1, g...      N
# 211327  [globus:pim.general.pflegehinweis.waschen-1, g...      N
# 211328  [globus:pim.general.pflegehinweis.waschen-1, g...      N
# 211329  [globus:pim.damenfashion.rocklange-inmidirockl...      N
# 211330  [globus:pim.general.pflegehinweis.waschen-1, g...      N
# 211333  [globus:pim.damenfashion.rocklange-inmidirockl...      N
# 211334  [globus:pim.damenfashion.rocklange-inmidirockl...      N
# 211335  [globus:pim.general.pflegehinweis.waschen-0, g...      N
# 211519  [globus:pim.damenfashion.rocklange-inmidirockl...      N
# 211520  [globus:pim.damenfashion.rocklange-inmidirockl...      N
# 211545  [globus:pim.general.pflegehinweis.waschen-0, g...      N
# 211553  [globus:pim.general.pflegehinweis.waschen-0, g...      N
#
#                                       hierarchy_full  \
# 35      globus:pim.category.damenaccessoires.taschen
# 36      globus:pim.category.damenaccessoires.taschen
# 37      globus:pim.category.damenaccessoires.taschen
# 38      globus:pim.category.damenaccessoires.taschen
# 39      globus:pim.category.damenaccessoires.taschen
# 40      globus:pim.category.damenaccessoires.taschen
# 46      globus:pim.category.damenaccessoires.taschen
# 71                 globus:pim.category.kinder.schuhe
# 84                 globus:pim.category.herren.hemden
# 112                 globus:pim.category.herren.hosen
# 114                 globus:pim.category.herren.hosen
# 118                 globus:pim.category.herren.hosen
# 311     globus:pim.category.damenaccessoires.taschen
# 319     globus:pim.category.damenaccessoires.taschen
# 320     globus:pim.category.damenaccessoires.taschen
# 321     globus:pim.category.damenaccessoires.taschen
# 322     globus:pim.category.damenaccessoires.taschen
# 323     globus:pim.category.damenaccessoires.taschen
# 324     globus:pim.category.damenaccessoires.taschen
# 325     globus:pim.category.damenaccessoires.taschen
# 326     globus:pim.category.damenaccessoires.taschen
# 327     globus:pim.category.damenaccessoires.taschen
# 328     globus:pim.category.damenaccessoires.taschen
# 329     globus:pim.category.damenaccessoires.taschen
# 354                globus:pim.category.herren.hemden
# 355                globus:pim.category.herren.hemden
# 358                globus:pim.category.herren.hemden
# 359                globus:pim.category.herren.hemden
# 393        globus:pim.category.damen.pullover-strick
# 394        globus:pim.category.damen.pullover-strick
# ...                                              ...
# 204092             globus:pim.category.herren.hemden
# 204093             globus:pim.category.herren.hemden
# 204094             globus:pim.category.herren.hemden
# 204095             globus:pim.category.herren.hemden
# 204096             globus:pim.category.herren.hemden
# 204105             globus:pim.category.herren.hemden
# 205978   globus:pim.category.damen.top-shirts-sweats
# 205982      globus:pim.category.damen.blusen-tuniken
# 205984      globus:pim.category.damen.blusen-tuniken
# 206246             globus:pim.category.damen.kleider
# 206251   globus:pim.category.damen.top-shirts-sweats
# 206281   globus:pim.category.damen.top-shirts-sweats
# 206787               globus:pim.category.damen.hosen
# 206805     globus:pim.category.damen.pullover-strick
# 206814               globus:pim.category.damen.hosen
# 210058             globus:pim.category.herren.hemden
# 210454  globus:pim.category.damenaccessoires.taschen
# 210533             globus:pim.category.herren.schuhe
# 211313     globus:pim.category.damen.pullover-strick
# 211327     globus:pim.category.damen.pullover-strick
# 211328     globus:pim.category.damen.pullover-strick
# 211329             globus:pim.category.damen.kleider
# 211330     globus:pim.category.damen.pullover-strick
# 211333             globus:pim.category.damen.kleider
# 211334             globus:pim.category.damen.kleider
# 211335      globus:pim.category.damen.blusen-tuniken
# 211519             globus:pim.category.damen.kleider
# 211520             globus:pim.category.damen.kleider
# 211545      globus:pim.category.damen.blusen-tuniken
# 211553      globus:pim.category.damen.blusen-tuniken
#
#                                                      href        prod_id  \
# 35      https://apitest.censhare.globus.ch/products/53...  1066588800528
# 36      https://apitest.censhare.globus.ch/products/53...  1066588800739
# 37      https://apitest.censhare.globus.ch/products/53...  1066588800820
# 38      https://apitest.censhare.globus.ch/products/53...  1066588800620
# 39      https://apitest.censhare.globus.ch/products/53...  1066588800601
# 40      https://apitest.censhare.globus.ch/products/53...  1066588800000
# 46      https://apitest.censhare.globus.ch/products/53...  1066588800012
# 71      https://apitest.censhare.globus.ch/products/53...  1066697900003
# 84      https://apitest.censhare.globus.ch/products/53...  1066570700528
# 112     https://apitest.censhare.globus.ch/products/53...  1066575400330
# 114     https://apitest.censhare.globus.ch/products/53...  1066575400528
# 118     https://apitest.censhare.globus.ch/products/53...  1066575400820
# 311     https://apitest.censhare.globus.ch/products/53...  1066851400739
# 319     https://apitest.censhare.globus.ch/products/53...  1066851400701
# 320     https://apitest.censhare.globus.ch/products/53...  1066851400320
# 321     https://apitest.censhare.globus.ch/products/53...  1066851400809
# 322     https://apitest.censhare.globus.ch/products/53...  1066851400012
# 323     https://apitest.censhare.globus.ch/products/53...  1066851400230
# 324     https://apitest.censhare.globus.ch/products/53...  1066852700809
# 325     https://apitest.censhare.globus.ch/products/53...  1066852700811
# 326     https://apitest.censhare.globus.ch/products/53...  1066852700012
# 327     https://apitest.censhare.globus.ch/products/53...  1066852700800
# 328     https://apitest.censhare.globus.ch/products/53...  1066853000811
# 329     https://apitest.censhare.globus.ch/products/53...  1066853000809
# 354     https://apitest.censhare.globus.ch/products/53...  1066827800375
# 355     https://apitest.censhare.globus.ch/products/53...  1066827800575
# 358     https://apitest.censhare.globus.ch/products/53...  1066828000560
# 359     https://apitest.censhare.globus.ch/products/53...  1066828000565
# 393     https://apitest.censhare.globus.ch/products/53...  1066955700330
# 394     https://apitest.censhare.globus.ch/products/53...  1066955700701
# ...                                                   ...            ...
# 204092  https://apitest.censhare.globus.ch/products/20...  1261638900503
# 204093  https://apitest.censhare.globus.ch/products/20...  1261639100528
# 204094  https://apitest.censhare.globus.ch/products/20...  1261639100563
# 204095  https://apitest.censhare.globus.ch/products/20...  1261639200561
# 204096  https://apitest.censhare.globus.ch/products/20...  1261639200567
# 204105  https://apitest.censhare.globus.ch/products/20...  1262754800000
# 205978  https://apitest.censhare.globus.ch/products/20...  1267580300739
# 205982  https://apitest.censhare.globus.ch/products/20...  1267580700003
# 205984  https://apitest.censhare.globus.ch/products/20...  1267580900524
# 206246  https://apitest.censhare.globus.ch/products/20...  1267617900739
# 206251  https://apitest.censhare.globus.ch/products/20...  1267618300520
# 206281  https://apitest.censhare.globus.ch/products/20...  1267630600404
# 206787  https://apitest.censhare.globus.ch/products/20...  1267753100520
# 206805  https://apitest.censhare.globus.ch/products/20...  1267758800001
# 206814  https://apitest.censhare.globus.ch/products/20...  1267759400739
# 210058  https://apitest.censhare.globus.ch/products/20...  1262753300041
# 210454  https://apitest.censhare.globus.ch/products/20...  1268187400810
# 210533  https://apitest.censhare.globus.ch/products/20...  1266647200739
# 211313  https://apitest.censhare.globus.ch/products/20...  1268214300524
# 211327  https://apitest.censhare.globus.ch/products/20...  1268216100524
# 211328  https://apitest.censhare.globus.ch/products/20...  1268216200620
# 211329  https://apitest.censhare.globus.ch/products/20...  1268216300524
# 211330  https://apitest.censhare.globus.ch/products/20...  1268216400524
# 211333  https://apitest.censhare.globus.ch/products/20...  1268216600739
# 211334  https://apitest.censhare.globus.ch/products/20...  1268217400739
# 211335  https://apitest.censhare.globus.ch/products/20...  1268217700920
# 211519  https://apitest.censhare.globus.ch/products/20...  1268223200739
# 211520  https://apitest.censhare.globus.ch/products/20...  1268223300524
# 211545  https://apitest.censhare.globus.ch/products/20...  1268235300502
# 211553  https://apitest.censhare.globus.ch/products/20...  1268236000524
#
#              hierarchy_1        hierarchy_2 hierarchy_3
# 35      damenaccessoires            taschen         NaN
# 36      damenaccessoires            taschen         NaN
# 37      damenaccessoires            taschen         NaN
# 38      damenaccessoires            taschen         NaN
# 39      damenaccessoires            taschen         NaN
# 40      damenaccessoires            taschen         NaN
# 46      damenaccessoires            taschen         NaN
# 71                kinder             schuhe         NaN
# 84                herren             hemden         NaN
# 112               herren              hosen         NaN
# 114               herren              hosen         NaN
# 118               herren              hosen         NaN
# 311     damenaccessoires            taschen         NaN
# 319     damenaccessoires            taschen         NaN
# 320     damenaccessoires            taschen         NaN
# 321     damenaccessoires            taschen         NaN
# 322     damenaccessoires            taschen         NaN
# 323     damenaccessoires            taschen         NaN
# 324     damenaccessoires            taschen         NaN
# 325     damenaccessoires            taschen         NaN
# 326     damenaccessoires            taschen         NaN
# 327     damenaccessoires            taschen         NaN
# 328     damenaccessoires            taschen         NaN
# 329     damenaccessoires            taschen         NaN
# 354               herren             hemden         NaN
# 355               herren             hemden         NaN
# 358               herren             hemden         NaN
# 359               herren             hemden         NaN
# 393                damen    pullover-strick         NaN
# 394                damen    pullover-strick         NaN
# ...                  ...                ...         ...
# 204092            herren             hemden         NaN
# 204093            herren             hemden         NaN
# 204094            herren             hemden         NaN
# 204095            herren             hemden         NaN
# 204096            herren             hemden         NaN
# 204105            herren             hemden         NaN
# 205978             damen  top-shirts-sweats         NaN
# 205982             damen     blusen-tuniken         NaN
# 205984             damen     blusen-tuniken         NaN
# 206246             damen            kleider         NaN
# 206251             damen  top-shirts-sweats         NaN
# 206281             damen  top-shirts-sweats         NaN
# 206787             damen              hosen         NaN
# 206805             damen    pullover-strick         NaN
# 206814             damen              hosen         NaN
# 210058            herren             hemden         NaN
# 210454  damenaccessoires            taschen         NaN
# 210533            herren             schuhe         NaN
# 211313             damen    pullover-strick         NaN
# 211327             damen    pullover-strick         NaN
# 211328             damen    pullover-strick         NaN
# 211329             damen            kleider         NaN
# 211330             damen    pullover-strick         NaN
# 211333             damen            kleider         NaN
# 211334             damen            kleider         NaN
# 211335             damen     blusen-tuniken         NaN
# 211519             damen            kleider         NaN
# 211520             damen            kleider         NaN
# 211545             damen     blusen-tuniken         NaN
# 211553             damen     blusen-tuniken         NaN
#
# [35533 rows x 16 columns]

# %% [markdown]
# # Get the dataframe with all the Globus attribute group names as column name:

# %%
def values_per_hierarchy2(features):
    h2_dict = {}
    for feature in features:
        split_tuple = feature.split('-', 1)
        h2_dict[split_tuple[0]] = split_tuple[1]
    return h2_dict

# %%
all_features=df_metadata['features']

# %%
exp_all_dictionaries = all_features.apply(values_per_hierarchy2)

# %%
exp_all_flat = exp_all_dictionaries.apply(pd.Series)

# %%
exp_all_flat.shape
# Out:
# (87055, 309)

# %%
exp_all_flat.columns[exp_all_flat.isin(['unifarben']).any()]
# Out:
# Index(['globus:pim.damenfashion.musterung', 'globus:pim.damenfashion.navmusterung'], dtype='object')

# %% [markdown]
# # Load the feature name of the model output layer & format it

# %%
features = pd.read_csv('../4_post_processing/features.csv', header=None )
features.columns=['features']

# %% [markdown]
# ## Split the unique feature names (the output labels of our model) into 2 parts: "attribute-group" and "attribute"

# %%
list_features=features['features']
attr_group=[]
attributes=[]

for i in list_features:
    if ('-' in i):
        attr_group.append(i.split('-')[0])
        attributes.append(i.split('-')[1])
        
    else:
        attr_group.append('attribute not known')
        attributes.append(i)

# %%
features['attribute_group']=attr_group
features['attribute']=attributes

# %%
features.head()
# Out:
#                 features attribute_group    attribute
# 0  absatzart-blockabsatz       absatzart  blockabsatz
# 1        absatzart-flach       absatzart        flach
# 2           anlass-abend          anlass        abend
# 3        anlass-business          anlass     business
# 4          anlass-casual          anlass       casual

# %% [markdown]
# # Map the Globus attribute group names to the features

# %%
# Check whether the unique feature (listed in features['attribute']) is included in the table of exp_all_flat. 
# If feature is found, take the column name 'globus_attr_group' and add it to list_groups.
list_groups=[]

for col in features['attribute']:
    names=exp_all_flat.columns[exp_all_flat.isin([col]).any()]
    list_groups.append(names)

# %%
features['globus_attr_group']=list_groups

# %%
features['globus_attr_group']=features['globus_attr_group'].apply(list)

# %%
features.head()
# Out:
#                 features attribute_group    attribute  \
# 0  absatzart-blockabsatz       absatzart  blockabsatz
# 1        absatzart-flach       absatzart        flach
# 2           anlass-abend          anlass        abend
# 3        anlass-business          anlass     business
# 4          anlass-casual          anlass       casual
#
#                     globus_attr_group
# 0  [globus:pim.accessoires.absatzart]
# 1  [globus:pim.accessoires.absatzart]
# 2    [globus:pim.damenfashion.anlass]
# 3    [globus:pim.damenfashion.anlass]
# 4    [globus:pim.damenfashion.anlass]

# %% [markdown]
# ## Cleaning is required, because the same feature name (e.g "unifarben") can be mapped to multiple globus attribute groups ('globus:pim.damenfashion.navmusterung' or 'globus:pim.damenfashion.musterung')

# %%
features
# Out:
#                                                          features  \
# 0    absatzart-blockabsatz
# 1    absatzart-flach
# 2    anlass-abend
# 3    anlass-business
# 4    anlass-casual
# 5    anlass-freizeit
# 6    anthrazit
# 7    armabschluss-manschettenmiteinemknopf
# 8    armabschluss-mitverstellbarenmanschetten
# 9    armelform-raglanarmel
# 10   armellange-34armlange
# 11   armellange-kurzarm
# 12   armellange-langarm
# 13   armellange-ohnearm
# 14   ausschnittkragenform-blusenkragen
# 15   ausschnittkragenform-kapuzenkragen
# 16   ausschnittkragenform-polokragen
# 17   ausschnittkragenform-rundhalsausschnitt
# 18   ausschnittkragenform-stehkragen
# 19   ausschnittkragenform-vausschnitt
# 20   beidesaison
# 21   beige
# 22   besonderheiten-abnehmbarerlaengenverstellbarerschulterriemen
# 23   besonderheiten-anhaenger
# 24   besonderheiten-applikationen
# 25   besonderheiten-fransen
# 26   besonderheiten-glitzerapplikationen
# 27   besonderheiten-goldfarbenedetails
# 28   besonderheiten-mitschoenerraffung
# 29   besonderheiten-mitunterkleid
# ..                            ...
# 154  taschen-schragertascheneingriff
# 155  trocknen-0
# 156  trocknen-1
# 157  trocknen-2
# 158  verschlussartfashion-druckknopfe
# 159  verschlussartfashion-knopfe
# 160  verschlussartfashion-magnetverschluss
# 161  verschlussartfashion-reisverschluss
# 162  verschlussartfashion-riegelverschluss
# 163  verschlussartfashion-schnurung
# 164  verschlussschuhe-reissverschluss
# 165  verschlussschuhe-zumschlupfen
# 166  verschlussschuhe-zumschnuren
# 167  waschen-0
# 168  waschen-1
# 169  waschen-2
# 170  waschen-3
# 171  waschen-4
# 172  waschen-F
# 173  waschen-G
# 174  webart-Strukturstrick
# 175  webart-ausjersey
# 176  webart-chambraygewebeleichtstrukturierteroptik
# 177  webart-feineschiffongewebe
# 178  webart-gewebemitflacheroptik
# 179  webart-oxfordgewebestrukturierteroptik
# 180  webart-popelinegewebeflacheroptik
# 181  webart-strick
# 182  webart-twillgewebeleichterschragverlaufenderstruktur
# 183  winter
#
#           attribute_group                                      attribute  \
# 0    absatzart             blockabsatz
# 1    absatzart             flach
# 2    anlass                abend
# 3    anlass                business
# 4    anlass                casual
# 5    anlass                freizeit
# 6    attribute not known   anthrazit
# 7    armabschluss          manschettenmiteinemknopf
# 8    armabschluss          mitverstellbarenmanschetten
# 9    armelform             raglanarmel
# 10   armellange            34armlange
# 11   armellange            kurzarm
# 12   armellange            langarm
# 13   armellange            ohnearm
# 14   ausschnittkragenform  blusenkragen
# 15   ausschnittkragenform  kapuzenkragen
# 16   ausschnittkragenform  polokragen
# 17   ausschnittkragenform  rundhalsausschnitt
# 18   ausschnittkragenform  stehkragen
# 19   ausschnittkragenform  vausschnitt
# 20   attribute not known   beidesaison
# 21   attribute not known   beige
# 22   besonderheiten        abnehmbarerlaengenverstellbarerschulterriemen
# 23   besonderheiten        anhaenger
# 24   besonderheiten        applikationen
# 25   besonderheiten        fransen
# 26   besonderheiten        glitzerapplikationen
# 27   besonderheiten        goldfarbenedetails
# 28   besonderheiten        mitschoenerraffung
# 29   besonderheiten        mitunterkleid
# ..              ...                  ...
# 154  taschen               schragertascheneingriff
# 155  trocknen              0
# 156  trocknen              1
# 157  trocknen              2
# 158  verschlussartfashion  druckknopfe
# 159  verschlussartfashion  knopfe
# 160  verschlussartfashion  magnetverschluss
# 161  verschlussartfashion  reisverschluss
# 162  verschlussartfashion  riegelverschluss
# 163  verschlussartfashion  schnurung
# 164  verschlussschuhe      reissverschluss
# 165  verschlussschuhe      zumschlupfen
# 166  verschlussschuhe      zumschnuren
# 167  waschen               0
# 168  waschen               1
# 169  waschen               2
# 170  waschen               3
# 171  waschen               4
# 172  waschen               F
# 173  waschen               G
# 174  webart                Strukturstrick
# 175  webart                ausjersey
# 176  webart                chambraygewebeleichtstrukturierteroptik
# 177  webart                feineschiffongewebe
# 178  webart                gewebemitflacheroptik
# 179  webart                oxfordgewebestrukturierteroptik
# 180  webart                popelinegewebeflacheroptik
# 181  webart                strick
# 182  webart                twillgewebeleichterschragverlaufenderstruktur
# 183  attribute not known   winter
#
#                                                                                                                         globus_attr_group
# 0    [globus:pim.accessoires.absatzart]
# 1    [globus:pim.accessoires.absatzart]
# 2    [globus:pim.damenfashion.anlass]
# 3    [globus:pim.damenfashion.anlass]
# 4    [globus:pim.damenfashion.anlass]
# 5    [globus:pim.kinder.anlass]
# 6    []
# 7    [globus:pim.damenfashion.armabschluss]
# 8    [globus:pim.damenfashion.armabschluss]
# 9    [globus:pim.damenfashion.armelform]
# 10   [globus:pim.damenfashion.armellange]
# 11   [globus:pim.damenfashion.armellange]
# 12   [globus:pim.damenfashion.armellange]
# 13   [globus:pim.damenfashion.armellange]
# 14   [globus:pim.damenfashion.ausschnittkragenform]
# 15   [globus:pim.damenfashion.ausschnittkragenform]
# 16   [globus:pim.damenfashion.ausschnittkragenform]
# 17   [globus:pim.damenfashion.ausschnittkragenform]
# 18   [globus:pim.damenfashion.ausschnittkragenform]
# 19   [globus:pim.damenfashion.ausschnittkragenform]
# 20   []
# 21   []
# 22   [globus:pim.accessoires.besonderheiten]
# 23   [globus:pim.accessoires.besonderheiten]
# 24   [globus:pim.herrenfashion.besonderheiten, globus:pim.damenfashion.besonderheiten]
# 25   [globus:pim.accessoires.besonderheiten]
# 26   [globus:pim.accessoires.besonderheiten, globus:pim.damenfashion.besonderheiten]
# 27   [globus:pim.accessoires.besonderheiten]
# 28   [globus:pim.damenfashion.besonderheiten]
# 29   [globus:pim.damenfashion.besonderheiten]
# ..                                        ...
# 154  [globus:pim.damenfashion.taschen]
# 155  [globus:pim.general.pflegehinweis.chemReinigen, globus:pim.general.pflegehinweis.buegeln, globus:pim.general.pflegehinweis.trocknen]
# 156  [globus:pim.general.pflegehinweis.chemReinigen, globus:pim.general.pflegehinweis.buegeln, globus:pim.general.pflegehinweis.trocknen]
# 157  [globus:pim.general.pflegehinweis.chemReinigen, globus:pim.general.pflegehinweis.buegeln, globus:pim.general.pflegehinweis.trocknen]
# 158  [globus:pim.damenfashion.verschlussartfashion]
# 159  [globus:pim.damenfashion.verschlussartfashion]
# 160  [globus:pim.damenfashion.verschlussartfashion]
# 161  [globus:pim.damenfashion.verschlussartfashion]
# 162  [globus:pim.damenfashion.verschlussartfashion]
# 163  [globus:pim.damenfashion.verschlussartfashion]
# 164  [globus:pim.accessoires.verschlussschuhe]
# 165  [globus:pim.accessoires.verschlussschuhe]
# 166  [globus:pim.accessoires.verschlussschuhe]
# 167  [globus:pim.general.pflegehinweis.waschen, globus:pim.general.pflegehinweis.bleichen, globus:pim.general.pflegehinweis.trocknen]
# 168  [globus:pim.general.pflegehinweis.waschen, globus:pim.general.pflegehinweis.bleichen, globus:pim.general.pflegehinweis.trocknen]
# 169  [globus:pim.general.pflegehinweis.waschen, globus:pim.general.pflegehinweis.bleichen, globus:pim.general.pflegehinweis.trocknen]
# 170  [globus:pim.general.pflegehinweis.waschen, globus:pim.general.pflegehinweis.buegeln]
# 171  [globus:pim.general.pflegehinweis.waschen]
# 172  [globus:pim.general.pflegehinweis.waschen]
# 173  [globus:pim.general.pflegehinweis.waschen]
# 174  [globus:pim.damenfashion.webart]
# 175  [globus:pim.damenfashion.webart]
# 176  [globus:pim.damenfashion.webart]
# 177  [globus:pim.damenfashion.webart]
# 178  [globus:pim.damenfashion.webart]
# 179  [globus:pim.damenfashion.webart]
# 180  [globus:pim.damenfashion.webart]
# 181  [globus:pim.damenfashion.webart]
# 182  [globus:pim.damenfashion.webart]
# 183  []
#
# [184 rows x 4 columns]

# %%
# cleaning - Remove the group name if the "attribute_group" is not in the name of "globus attribute group":
def cleaning_function(row):
    keep=[el for el in row['globus_attr_group'] if row['attribute_group'] in el]
    return keep

# %%
features.iloc[155]
# Out:
# features                                              trocknen-0
# attribute_group                                         trocknen
# attribute                                                      0
# globus_attr_group    [globus:pim.general.pflegehinweis.trocknen]
# Name: 155, dtype: object

# %%
features['globus_attr_group']=features.apply(cleaning_function, axis=1)

# %%
features.head()
# Out:
#                 features attribute_group    attribute  \
# 0  absatzart-blockabsatz       absatzart  blockabsatz
# 1        absatzart-flach       absatzart        flach
# 2           anlass-abend          anlass        abend
# 3        anlass-business          anlass     business
# 4          anlass-casual          anlass       casual
#
#                     globus_attr_group
# 0  [globus:pim.accessoires.absatzart]
# 1  [globus:pim.accessoires.absatzart]
# 2    [globus:pim.damenfashion.anlass]
# 3    [globus:pim.damenfashion.anlass]
# 4    [globus:pim.damenfashion.anlass]

# %%
pd.set_option('display.max_colwidth',-1)
features[features['globus_attr_group'].str.len()>1]
# Out:
#                                features attribute_group             attribute  \
# 24  besonderheiten-applikationen         besonderheiten  applikationen
# 26  besonderheiten-glitzerapplikationen  besonderheiten  glitzerapplikationen
# 99  musterung-unifarben                  musterung       unifarben
#
#                                                                     globus_attr_group
# 24  [globus:pim.herrenfashion.besonderheiten, globus:pim.damenfashion.besonderheiten]
# 26  [globus:pim.accessoires.besonderheiten, globus:pim.damenfashion.besonderheiten]
# 99  [globus:pim.damenfashion.musterung, globus:pim.damenfashion.navmusterung]

# %%
len(features[features['globus_attr_group'].str.len()>1])
# Out:
# 3

# %%
features[features['globus_attr_group'].str.len()==0]
# Out:
#                   features      attribute_group        attribute  \
# 6    anthrazit              attribute not known  anthrazit
# 20   beidesaison            attribute not known  beidesaison
# 21   beige                  attribute not known  beige
# 35   bordeaux               attribute not known  bordeaux
# 36   braun                  attribute not known  braun
# 47   ecru                   attribute not known  ecru
# 52   futtermaterial-L18     futtermaterial       L18
# 53   futtermaterial-PES     futtermaterial       PES
# 54   futtermaterial-textil  futtermaterial       textil
# 58   grün                   attribute not known  grün
# 59   hellblau               attribute not known  hellblau
# 72   klein gemustert        attribute not known  klein gemustert
# 79   material-CAC           material             CAC
# 80   material-CMD           material             CMD
# 81   material-CO            material             CO
# 82   material-CV            material             CV
# 83   material-EL            material             EL
# 84   material-L1            material             L1
# 85   material-L18           material             L18
# 86   material-L2            material             L2
# 87   material-LI            material             LI
# 88   material-MER           material             MER
# 89   material-PA            material             PA
# 90   material-PES           material             PES
# 91   material-PU            material             PU
# 92   material-SE            material             SE
# 93   material-WO            material             WO
# 124  offwhite               attribute not known  offwhite
# 129  pink                   attribute not known  pink
# 142  regularfit             attribute not known  regularfit
# 144  rosa                   attribute not known  rosa
# 149  slimfit                attribute not known  slimfit
# 150  sommer                 attribute not known  sommer
# 151  tailliert              attribute not known  tailliert
# 183  winter                 attribute not known  winter
#
#     globus_attr_group
# 6    []
# 20   []
# 21   []
# 35   []
# 36   []
# 47   []
# 52   []
# 53   []
# 54   []
# 58   []
# 59   []
# 72   []
# 79   []
# 80   []
# 81   []
# 82   []
# 83   []
# 84   []
# 85   []
# 86   []
# 87   []
# 88   []
# 89   []
# 90   []
# 91   []
# 92   []
# 93   []
# 124  []
# 129  []
# 142  []
# 144  []
# 149  []
# 150  []
# 151  []
# 183  []

# %%
len(features[features['globus_attr_group'].str.len()==0])
# Out:
# 35

# %% [markdown]
# # These features (colors, material codes, seasons) have no globus attribute group name:

# %%
exp_all_flat.columns[exp_all_flat.isin(['pink']).any()]
# Out:
# Index([], dtype='object')

# %%
exp_all_flat.columns[exp_all_flat.isin(['slimfit']).any()]
# Out:
# Index([], dtype='object')

# %%
exp_all_flat.columns[exp_all_flat.isin(['regularfit']).any()]
# Out:
# Index([], dtype='object')

# %%
exp_all_flat.columns[exp_all_flat.isin(['L18']).any()]
# Out:
# Index([], dtype='object')

# %%
exp_all_flat.columns[exp_all_flat.isin(['grün']).any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# # Keep only the features, which can be clearly mapped to 1 single globus attribute group:

# %%
features_with_attribute_group=features[features['globus_attr_group'].str.len()==1]

# %%
len(features_with_attribute_group)
# Out:
# 146

# %%
features_with_attribute_group.head()
# Out:
#                 features attribute_group    attribute  \
# 0  absatzart-blockabsatz  absatzart       blockabsatz
# 1  absatzart-flach        absatzart       flach
# 2  anlass-abend           anlass          abend
# 3  anlass-business        anlass          business
# 4  anlass-casual          anlass          casual
#
#                     globus_attr_group
# 0  [globus:pim.accessoires.absatzart]
# 1  [globus:pim.accessoires.absatzart]
# 2  [globus:pim.damenfashion.anlass]
# 3  [globus:pim.damenfashion.anlass]
# 4  [globus:pim.damenfashion.anlass]

# %%
features_with_attribute_group.to_csv('features_mapped_to_globus_attribute_groups.csv')

# %% [markdown]
# # Features with 0 or more than 1 attribute groups:

# %%
features_with_0_attribute_group=features[features['globus_attr_group'].str.len()==0]
features_with_multiple_attribute_groups=features[features['globus_attr_group'].str.len()>1]

# %%
features_with_0_attribute_group.to_csv('features_with_0_attribute_groups.csv')
features_with_multiple_attribute_groups.to_csv('features_with_multiple_attribute_groups.csv')

# %% [markdown]
# # Add the column with the Globus attribute group name and save the csv

# %%
features['globus_attr_group_to_use']=features['globus_attr_group'].where(features['globus_attr_group'].str.len()==1, '')

# %%
features_with_attribute_group=features[['features','attribute_group', 'attribute', 'globus_attr_group_to_use']]

# %%
features_with_attribute_group.shape
# Out:
# (184, 4)

# %%
features_with_attribute_group.to_csv('features_mapped_to_globus_attribute_groups.csv')
