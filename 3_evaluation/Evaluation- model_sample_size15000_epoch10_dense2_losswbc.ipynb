# %%
# Import
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ast import literal_eval
from collections import Counter
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop

import seaborn as sns
import pickle
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras import backend as K
# import helper functions
import sys
# add our pipeline folder to the path to import functions
sys.path.insert(1, '../2_modeling')
from model_helper_no_cache import *
# %matplotlib inline

from sklearn.metrics import roc_curve, auc


"""
nb_extensions
https://github.com/ipython-contrib/jupyter_contrib_nbextensions/blob/master/README.md
https://github.com/Jupyter-contrib/jupyter_nbextensions_configurator/blob/master/README.md
"""
# Out:
# '\nnb_extensions\nhttps://github.com/ipython-contrib/jupyter_contrib_nbextensions/blob/master/README.md\nhttps://github.com/Jupyter-contrib/jupyter_nbextensions_configurator/blob/master/README.md\n'

# %% [markdown]
# # List the files of saved models

# %%
# Path
models_path = '../../efs/models'
checkpoint_path='../../efs/models/Checkpoints/'
training_history_path='../../efs/models/Training_history/'
saved_models_path='../../efs/models/Saved_models/'

# %%
os.listdir(checkpoint_path)
# Out:
# ['model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_1_penalty_weight_10.ckpt.data-00000-of-00002',
#  'model__sample_size_500_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10featuresextended.ckpt.data-00000-of-00002',
#  'model__sample_size_500_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10featuresextended.ckpt.index',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_1_penalty_weight_10.ckpt.index',
#  'model_no_cache_test_sample_size_all_epoch_2_dense_2_neurons_256_losswbc__num_open_layers_1_penalty_weight_10.ckpt.data-00000-of-00002',
#  'checkpoint',
#  'model_no_cache_test_sample_size_all_epoch_2_dense_2_neurons_256_losswbc__num_open_layers_1_penalty_weight_10.ckpt.index',
#  'model_no_cache_test_sample_size_all_epoch_20_dense_2_neurons_512_losswbc__num_open_layers_2_penalty_weight_10.ckpt.index',
#  'model_no_cache_test_sample_size_14000_epoch_2_dense_2_neurons_256_losswbc__num_open_layers_1_penalty_weight_10.ckpt.data-00000-of-00002',
#  'model_no_cache_test_sample_size_14000_epoch_2_dense_2_neurons_256_losswbc__num_open_layers_1_penalty_weight_10.ckpt.index',
#  'model_sample_size15000_epoch10_dense2_losswbc.ckpt.data-00001-of-00002',
#  'model_no_cache_test_sample_size_all_epoch_20_dense_2_neurons_512_losswbc__num_open_layers_2_penalty_weight_10.ckpt.data-00000-of-00002',
#  'model2_sample_sizeall_epoch50_dense2_losswbc.ckpt.index',
#  'model3_sample_size1500015k_epoch5 _dense2_losswbc.ckpt.data-00001-of-00002',
#  'model2_sample_sizeall_epoch50_dense2_losswbc.ckpt.data-00000-of-00002',
#  'model1_sample_sizeall_epoch50_dense2_losswbc.ckpt.data-00001-of-00002',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10.ckpt.data-00001-of-00002',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10featuresextended.ckpt.data-00001-of-00002',
#  'model3_sample_size15k_epoch50_dense2_losswbc.ckpt.data-00001-of-00002',
#  'model_sample_size15000_epoch20_dense2neurons1024_losswbc.ckpt.data-00001-of-00002',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_1.ckpt.data-00001-of-00002',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10.ckpt.index',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10featuresextended.ckpt.index',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10featuresextended.ckpt.data-00000-of-00002',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_1_penalty_weight_10.ckpt.data-00001-of-00002',
#  'model__sample_size_500_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10featuresextended.ckpt.data-00001-of-00002',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10.ckpt.data-00000-of-00002',
#  'model_no_cache_test_sample_size_all_epoch_2_dense_2_neurons_256_losswbc__num_open_layers_1_penalty_weight_10.ckpt.data-00001-of-00002',
#  'model3_sample_size15k_epoch50_dense2_losswbc.ckpt.index',
#  'model_no_cache_test_sample_size_all_epoch_20_dense_2_neurons_512_losswbc__num_open_layers_2_penalty_weight_10.ckpt.data-00001-of-00002',
#  'model_sample_size15000_epoch20_dense2neurons1024_losswbc.ckpt.index',
#  'model_sample_size15000_epoch20_dense2neurons1024_losswbc.ckpt.data-00000-of-00002',
#  'model_no_cache_test_sample_size_14000_epoch_2_dense_2_neurons_256_losswbc__num_open_layers_1_penalty_weight_10.ckpt.data-00001-of-00002',
#  'model3_sample_size15k_epoch50_dense2_losswbc.ckpt.data-00000-of-00002',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_1.ckpt.index',
#  'model2_sample_sizeall_epoch50_dense2_losswbc.ckpt.data-00001-of-00002',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_1.ckpt.data-00000-of-00002',
#  'model_sample_size15000_epoch10_dense2_losswbc.ckpt.data-00000-of-00002',
#  'model_sample_size15000_epoch10_dense2_losswbc.ckpt.index',
#  'model1_sample_sizeall_epoch50_dense2_losswbc.ckpt.data-00000-of-00002',
#  'model3_sample_size1500015k_epoch5 _dense2_losswbc.ckpt.index',
#  'model3_sample_size1500015k_epoch5 _dense2_losswbc.ckpt.data-00000-of-00002',
#  'model1_sample_sizeall_epoch50_dense2_losswbc.ckpt.index']

# %%
os.listdir(training_history_path)
# Out:
# ['model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_1_penalty_weight_10.pickle',
#  'model_no_cache_test_sample_size_all_epoch_20_dense_2_neurons_512_losswbc__num_open_layers_2_penalty_weight_10.pickle',
#  'model2_sample_sizeall_epoch50_dense2_losswbc_history_log.csv',
#  'model_no_cache_test_sample_size_14000_epoch_2_dense_2_neurons_256_losswbc__num_open_layers_1_penalty_weight_10_history_log.csv',
#  'model_no_cache_test_sample_size_all_epoch_20_dense_2_neurons_512_losswbc__num_open_layers_2_penalty_weight_10_history_log.csv',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_1_penalty_weight_10_history_log.csv',
#  'model__sample_size_500_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10featuresextended_history_log.csv',
#  'model_no_cache_test_sample_size_all_epoch_2_dense_2_neurons_256_losswbc__num_open_layers_1_penalty_weight_10_history_log.csv',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10featuresextended.pickle',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10.pickle',
#  'model3_sample_size1500015k_epoch5 _dense2_losswbc_history_log.csv',
#  'model_sample_size15000_epoch10_dense2_losswbc_history_log.csv',
#  'model_sample_size15000_epoch20_dense2neurons1024_losswbc.pickle',
#  'model_sample_size15000_epoch10_dense2_losswbc.pickle',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_1_history_log.csv',
#  'model_sample_size15000_epoch20_dense2neurons1024_losswbc_history_log.csv',
#  'model3_sample_size1500015k_epoch5 _dense2_losswbc.pickle',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10featuresextended_history_log.csv',
#  'model__sample_size_15000_epoch_20_dense_2_neurons_1024_losswbc__num_open_layers_2_penalty_weight_10_history_log.csv']

# %% [markdown]
# # Set the parameter

# %%
weights='model_sample_size15000_epoch10_dense2_losswbc'

csv = '../1_cleaning/metadata_cleaned.csv'

number_of_images = 15000

history=weights+'.pickle'

# %%
# Create train-test dataset
#name_of_model='model1_sample_sizeall_epoch50_dense2_losswbc'
# Test train split, plus the features that are used to binarize the data
X_train, X_val, y_train_bin, y_val_bin, features = train_test_split_custom(number_of_images, csv)

# %% [markdown]
# # Load the model

# %% [markdown]
# ## Option 1 : load the saved model:

# %%
# Load the model
new_model = tf.keras.models.load_model('../../efs/models/Saved_models/' + weights + '.h5', /
                                       custom_objects={'weighted_bce': weighted_bce, 
                                                       'accuracy_on_zero': accuracy_on_zero,
                                                       'accuracy_on_one': accuracy_on_one, 
                                                       'precision_on_1': precision_on_1})

# %% [markdown]
# ## Option 2:  load the architecture + weights

# %%
# Architecture
vgg = VGG19(include_top=False, weights='imagenet', input_shape=(224,224,3))

transfer_layer = vgg.get_layer('block5_pool')

# cutting of the end of the model before the dense layers
conv_model = Model(inputs=vgg.input,
                   outputs=transfer_layer.output)

# freeze VGG
conv_model.trainable = False

num_label = y_train_bin.shape[1]

def create_model():
    # Start a new Keras Sequential model.
    model = Sequential()

    # Add the convolutional part of the VGG16 model from above.
    model.add(conv_model)

    # Flatten the output of the VGG16 model because it is from a
    # convolutional layer.
    model.add(Flatten())

    # Add a dense (aka. fully-connected) layer.
    # This is for combining features that the VGG16 model has
    # recognized in the image.
    model.add(Dense(1024, activation='relu'))

    model.add(Dropout(0.2))
    
    model.add(Dense(1024, activation='relu'))

    model.add(Dropout(0.2))

    model.add(Dense(num_label, activation='sigmoid'))
    
    # Settings
    LR = 1e-5
    optimizer = Adam(lr=LR)
    loss = weighted_bce
    metrics = [accuracy_on_one, accuracy_on_zero]
    
    model.compile(optimizer=optimizer, 
                  loss=loss, 
                  metrics=metrics)
    
    return model


new_model=create_model()

# %%
# Checkpoint path
# For weights to be saved each epoch
#checkpoint_path = '../../efs/models/Checkpoints/' + weights + '.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

# Loads the weights from the checkpoint path above
new_model.load_weights(checkpoint_path+weights+'.ckpt')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-291e72beeda7> in <module>()
#       5
#       6 # Loads the weights from the checkpoint path above
# ----> 7 new_model.load_weights(checkpoint_path+weights+'.ckpt')
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in load_weights(self, filepath, by_name)
#     179         raise ValueError('Load weights is not yet supported with TPUStrategy '
#     180                          'with steps_per_run greater than 1.')
# --> 181     return super(Model, self).load_weights(filepath, by_name)
#     182
#     183   @trackable.no_automatic_dependency_tracking
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in load_weights(self, filepath, by_name)
#    1147         save_format = 'h5'
#    1148     if save_format == 'tf':
# -> 1149       status = self._trackable_saver.restore(filepath)
#    1150       if by_name:
#    1151         raise NotImplementedError(
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/training/tracking/util.py in restore(self, save_path)
#    1268         graph_view=self._graph_view)
#    1269     base.CheckpointPosition(
# -> 1270         checkpoint=checkpoint, proto_id=0).restore(self._graph_view.root)
#    1271     load_status = CheckpointLoadStatus(
#    1272         checkpoint,
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/training/tracking/base.py in restore(self, trackable)
#     207         # This object's correspondence with a checkpointed object is new, so
#     208         # process deferred restorations for it and its dependencies.
# --> 209         restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     210         if restore_ops:
#     211           self._checkpoint.new_restore_ops(restore_ops)
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/training/tracking/base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     906     restore_ops.extend(
#     907         current_position.checkpoint.restore_saveables(
# --> 908             tensor_saveables, python_saveables))
#     909     return restore_ops
#     910
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/training/tracking/util.py in restore_saveables(self, tensor_saveables, python_saveables)
#     287              "expecting %s") % (tensor_saveables.keys(), validated_names))
#     288       new_restore_ops = functional_saver.MultiDeviceSaver(
# --> 289           validated_saveables).restore(self.save_path_tensor)
#     290       if not context.executing_eagerly():
#     291         for name, restore_op in sorted(new_restore_ops.items()):
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/training/saving/functional_saver.py in restore(self, file_prefix)
#     256     for device, saver in sorted(self._single_device_savers.items()):
#     257       with ops.device(device):
# --> 258         restore_ops.update(saver.restore(file_prefix))
#     259     return restore_ops
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/training/saving/functional_saver.py in restore(self, file_prefix)
#     101                                           structured_restored_tensors):
#     102       restore_ops[saveable.name] = saveable.restore(
# --> 103           restored_tensors, restored_shapes=None)
#     104     return restore_ops
#     105
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/training/saving/saveable_object_util.py in restore(self, restored_tensors, restored_shapes)
#     113       restored_tensor = array_ops.identity(restored_tensor)
#     114       return resource_variable_ops.shape_safe_assign_variable_handle(
# --> 115           self.handle_op, self._var_shape, restored_tensor)
#     116
#     117
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py in shape_safe_assign_variable_handle(handle, shape, value, name)
#     289   with _handle_graph(handle):
#     290     value_tensor = ops.convert_to_tensor(value)
# --> 291   shape.assert_is_compatible_with(value_tensor.shape)
#     292   return gen_resource_variable_ops.assign_variable_op(handle,
#     293                                                       value_tensor,
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/tensorflow_core/python/framework/tensor_shape.py in assert_is_compatible_with(self, other)
#    1113     """
#    1114     if not self.is_compatible_with(other):
# -> 1115       raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#    1116
#    1117   def most_specific_compatible_shape(self, other):
#
# ValueError: Shapes (1024,) and (512,) are incompatible

# %% [markdown]
# # Model architecture

# %%
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Model)                (None, 7, 7, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 112)               114800
# =================================================================
# Total params: 46,879,920
# Trainable params: 26,855,536
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# # Predictions for the test dataset

# %%
# Create the datasets
# new_model.load_weights(checkpoint_path)
train_ds = create_dataset(X_train, y_train_bin)
val_ds = create_dataset(X_val, y_val_bin)

# %%
# Make the predictions
# %%time
# Takes 2:30 with 1000 images, 
# grab the predictions from the valadation ds
predictions_test = new_model.predict(val_ds)
#predictions_train = new_model.predict(train_ds)

# SAVE the prediction
#pickle.dump([predictions_test], open( "predictions.p", "wb" ) )
# Out:
# CPU times: user 1min 4s, sys: 14.4 s, total: 1min 18s
# Wall time: 40.7 s

# %%
# Optional step - load the predictions from file
#pickle.dump([predictions_test], open( "predictions.p", "wb" ) )
# Load the prediction
#predictions_test= pickle.load( open( "predictions.p", "rb" ) )

# %% [markdown]
# # Evaluations

# %% [markdown]
# ## Loss plots

# %%
# Load the training history
history=pickle.load(open(training_history_path+history, "rb" ))

# %%
# Plot the training history
plot_training_history_loss(history)

# %% [markdown]
# ## Model prediction on features that are present in photo

# %%
# Plot the predictions on 1s + the differences of medians 
plot_per_feature_error(predictions_test, y_val_bin, features, diff=True)
# Out:
# (<Figure size 1152x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f213953ef60>)

# %% [markdown]
# ## Recall on 1, recall on 0

# %%
plot_training_history_recall_on_one(history)

# %%
plot_training_history_recall_on_zero(history)

# %% [markdown]
# # Precision

# %%
plot_training_history_precision_on_one(history)

# %% [markdown]
# ## Make a prediction for an image

# %%
doPrediction(0, features, X_val, y_val_bin, predictions_test)

# %%
doPrediction(1,features, X_val, y_val_bin, predictions_test)

# %%
doPrediction(3,features, X_val, y_val_bin, predictions_test)

# %%
doPrediction(4,features, X_val, y_val_bin, predictions_test)

# %% [markdown]
# ## ROC AUC curve

# %%
grouped_roc(y_val_bin, predictions_test)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/metrics/ranking.py:659: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f212579cfd0>)

# %%
# Plot 3 ROC curves for 3 features
n_classes = y_val_bin.shape[1]

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

    
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], predictions_test[:, i], pos_label=1)
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure()
for i in range(3):
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# %%
# ROC AUC scores per feature
for i in range(119):
    fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], predictions_test[:, i], pos_label=1)
    roc_auc[i] = auc(fpr[i], tpr[i])
    
roc_auc
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/metrics/ranking.py:659: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# {0: 0.9957340508152432,
#  1: 0.9928496508735654,
#  2: 0.9447238387364374,
#  3: 0.9915518471317158,
#  4: 0.9578879248028951,
#  5: 0.9969690808979246,
#  6: 0.7752374067873993,
#  7: 0.9661675424387288,
#  8: 0.9879121632144526,
#  9: 0.8528017778780858,
#  10: 0.9579352747564867,
#  11: 0.9902697051503154,
#  12: 0.9922727406997633,
#  13: 0.987149308787534,
#  14: 0.9636344022035116,
#  15: 0.9919107088464384,
#  16: 0.9893501131643744,
#  17: 0.9697833775319279,
#  18: 0.9326915245402271,
#  19: 0.9441695105925203,
#  20: 0.8820081290997628,
#  21: 0.7994406836922384,
#  22: 0.9828800270396222,
#  23: 0.9748495652541537,
#  24: 0.9221700791609606,
#  25: 0.9835632583893646,
#  26: 0.8387204986878869,
#  27: 0.9654004706287419,
#  28: 0.9293710660316256,
#  29: 0.9775620299744556,
#  30: 0.933419870313074,
#  31: 0.981993474921208,
#  32: 0.9756150370040663,
#  33: 0.936867413537006,
#  34: 0.8533383863695039,
#  35: 0.780426652419478,
#  36: 0.8503538415005532,
#  37: 0.9210371584264143,
#  38: 0.8428547594491294,
#  39: 0.8681180830002048,
#  40: 0.8607414770819942,
#  41: 0.9963173253874926,
#  42: 0.8415638603914883,
#  43: 0.8075740572607978,
#  44: 0.8082541477724471,
#  45: 0.9859405542692049,
#  46: 0.9776544108249937,
#  47: 0.8809695379823872,
#  48: 0.9876082670803439,
#  49: 0.9991100905586603,
#  50: 0.9962505390067228,
#  51: 0.989062597056987,
#  52: 0.9901994893129479,
#  53: 0.9551356589147285,
#  54: 0.9831162469886141,
#  55: 0.9295970901258784,
#  56: 0.9515194712236685,
#  57: 0.9339667727979566,
#  58: 0.7655304651692536,
#  59: 0.8453556504890631,
#  60: nan,
#  61: 0.9789260536973151,
#  62: 0.993322965336033,
#  63: 0.9890211732847771,
#  64: 0.9939825753472016,
#  65: 0.9678996105882899,
#  66: 0.9735318664712304,
#  67: 0.9623911859534833,
#  68: 0.9697492964952673,
#  69: 0.967424341985689,
#  70: 0.9656721985869968,
#  71: 0.9516875198331747,
#  72: 0.9232590472086271,
#  73: 0.9872092822676886,
#  74: 0.9916620702679919,
#  75: 0.9854031356132196,
#  76: 0.988651520123288,
#  77: 0.9925824157911437,
#  78: 0.9789191799248116,
#  79: 0.9354692073810372,
#  80: 0.8717330501410816,
#  81: 0.9227219461587998,
#  82: 0.854943967357169,
#  83: 0.8852307379757278,
#  84: 0.9569389163084434,
#  85: 0.9434608308732297,
#  86: 0.958399680124187,
#  87: 0.8462332867897792,
#  88: 0.9386415281313537,
#  89: 0.8442582842524837,
#  90: 0.7968890623409237,
#  91: 0.9371398008014097,
#  92: 0.9098619243250886,
#  93: 0.8965191301484309,
#  94: 0.9605354976676714,
#  95: 0.8627734289955701,
#  96: 0.9491761448464942,
#  97: 0.9479514687196074,
#  98: 0.9227957015272163,
#  99: 0.9378697154288226,
#  100: 0.9393297144756252,
#  101: 0.9913881619714342,
#  102: 0.9987582319875823,
#  103: 0.9845136248415716,
#  104: 0.9778478218643499,
#  105: 0.9711017459361829,
#  106: 0.9922199763136946,
#  107: 0.990842440676728,
#  108: 0.9927521804055663,
#  109: 0.9912337174617482,
#  110: 0.8979010494752624,
#  111: 0.9913777282832201,
#  112: 0.9759878100042033,
#  113: 0.9925918723870041,
#  114: 0.9837450769781596,
#  115: 0.9742331648842402,
#  116: 0.9443477541422975,
#  117: 0.9412921376140428,
#  118: 0.975496715539346}
