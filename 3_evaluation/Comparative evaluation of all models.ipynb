# %%
# Import

# General
import os
import pandas as pd
import numpy as np
import pickle
from collections import Counter
import sys
import copy
import glob

# Import helper functions
from evaluation_helper import *

# Add our pipeline folder to the path to import functions
sys.path.insert(1, '../2_modeling')
from model_helper import *

#Plotting
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import matplotlib.image as mpimg
# %matplotlib inline

# Data Processing
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import roc_curve, auc

# Machine Learning
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras import backend as K

# %% [markdown]
# # List the files of saved models

# %%
# Paths
models_path = '../../efs/models'
checkpoint_path='../../efs/models/Checkpoints/'
training_history_path='../../efs/models/Training_history/'
saved_models_path='../../efs/models/Saved_models/'

# %%
# Option: List the training history file names
# os.listdir(training_history_path)

# %%
def check_number_of_epochs(min_number_of_epochs, path):
    """ check to see if the history has at least a certain number of epochs"""    
    
    frame = pd.read_csv(path)
    
    if frame.shape[0] > min_number_of_epochs:
        return True
    
    return False

# %%
# Grab all the paths of the csvs
csv_history_paths = glob.glob(training_history_path+'*.csv')

# filter for only that have 'all' samples
csv_history_paths_all = [path for path in csv_history_paths if path.find('all')!=-1]

# Set the minimum number of epochs for models we want to display
minimum_number_of_epochs = 10

histories = dict()

for path in csv_history_paths_all:
    try:
        if check_number_of_epochs(minimum_number_of_epochs, path):
            histories[grab_model_name(path)] = pd.read_csv(path)
    except:
        pass

# %%
# Create a list of all the dataframes with the correct columns
list_of_dfs = [frame_extraction(histories[path], path) for path in list(histories.keys())]
all_models = pd.concat(list_of_dfs)

# %%
# Change all the model names to something comprehensible
old_names = all_models.model.unique()
new_names = ['Single Input with 2 Dense Layers 512 Neurons and 2 open layers',
            'Single Input with 2 Dense Layers 1024 Neurons and 2 open layers',
            'Multiple Input with 2 Dense Layers 1024 Neurons and 2 open layers']

for new,old in zip(new_names, old_names):
    all_models.replace(old, new, inplace=True)

# %%
all_models.columns
# Out:
# Index(['epoch', 'val_precision_on_1', 'val_accuracy_on_zero',
#        'val_accuracy_on_one', 'model', 'f1'],
#       dtype='object')

# %%
xlims=-1,15
ylims=0,1

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.scatterplot(x='epoch', 
                y="val_accuracy_on_zero", 
                hue="model",
                s=100,
                data=all_models, ax=ax)
plt.legend(loc='lower right')
ax.set_xlim(xlims)
ax.set_ylim(ylims)
font_title={'size':30}
plt.title("Validation recall on zero", font_title)
font_axes={'size':20}
ax.set_xlabel("Epochs", font_axes)
ax.set_ylabel("Validation recall on zero", font_axes)
# Out:
# Text(0, 0.5, 'Validation recall on zero')

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(x='epoch', y="val_accuracy_on_one", hue="model",
                     data=all_models, ax=ax, lw=5)
ax.set_xlim((-1,30))
plt.title("Validation recall", font_title)
font_axes={'size':20}
ax.set_xlabel("Epochs", font_axes)
ax.set_ylabel("Validation recall", font_axes)
ax.set_xlim(xlims)
ax.set_ylim(ylims)
plt.legend(loc='lower right', prop={'size': 20})

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(x='epoch', y="val_precision_on_1", hue="model",
                     data=all_models, ax=ax, lw=5)

ax.set_xlim((-1,30))

plt.title("Validation precision", font_title)
font_axes={'size':20}
ax.set_xlabel("Epochs", font_axes)
ax.set_ylabel("Validation precision", font_axes)
plt.legend(loc='lower right', prop={'size': 20})
ax.set_xlim(xlims)
ax.set_ylim(ylims)
# Out:
# (0, 1)

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(x='epoch', 
                y="f1", 
                hue="model",
                lw=5,
                data=all_models, 
                ax=ax)
plt.legend(loc='lower right')
font_title={'size':30}
plt.title("F1 score", font_title)
font_axes={'size':20}
ax.set_xlabel("Epochs", font_axes)
ax.set_ylabel("F1", font_axes)

ax.set_xlim(-1,30)
ax.set_ylim(ylims)
plt.legend(loc='lower right', prop={'size': 20})

# %%
all_models
# Out:
#     epoch  val_precision_on_1  val_accuracy_on_zero  val_accuracy_on_one  \
# 0       0            0.328915              0.851541             0.869526
# 1       1            0.355474              0.864524             0.892767
# 2       2            0.365620              0.868657             0.904369
# 3       3            0.373750              0.872452             0.909330
# 4       4            0.378691              0.874623             0.912890
# 5       5            0.384315              0.877254             0.915279
# 6       6            0.388372              0.878952             0.918144
# 7       7            0.391002              0.879987             0.920430
# 8       8            0.394752              0.881764             0.921160
# 9       9            0.400237              0.884463             0.920994
# 10     10            0.401868              0.885114             0.921970
# 11     11            0.405241              0.886653             0.922509
# 12     12            0.407488              0.887625             0.923080
# 13     13            0.411897              0.889819             0.921739
# 14     14            0.411988              0.889667             0.923276
# 15     15            0.418210              0.892648             0.921645
# 16     16            0.420477              0.893735             0.920867
# 17     17            0.421795              0.894313             0.920825
# 18     18            0.422245              0.894384             0.921867
# 19     19            0.427635              0.896953             0.919557
# 0       0            0.349465              0.966731             0.802914
# 1       1            0.364389              0.967656             0.832937
# 2       2            0.370259              0.967973             0.845863
# 3       3            0.376231              0.968506             0.853279
# 4       4            0.380890              0.968961             0.857646
# 5       5            0.383288              0.969085             0.862933
# 6       6            0.387644              0.969586             0.864666
# 7       7            0.390052              0.969816             0.866959
# 8       8            0.391696              0.969934             0.869400
# 9       9            0.396980              0.970618             0.868627
# ..    ...                 ...                   ...                  ...
# 0       0            0.362379              0.869861             0.883744
# 1       1            0.383355              0.878988             0.898732
# 2       2            0.396103              0.884420             0.905624
# 3       3            0.402790              0.887114             0.909435
# 4       4            0.413943              0.892257             0.908950
# 5       5            0.417320              0.893487             0.911088
# 6       6            0.425316              0.897038             0.910020
# 7       7            0.427804              0.897977             0.910960
# 8       8            0.435686              0.901388             0.909157
# 9       9            0.440090              0.903234             0.908300
# 10     10            0.445438              0.905572             0.905823
# 11     11            0.448364              0.906673             0.905867
# 12     12            0.451686              0.907897             0.906068
# 13     13            0.456639              0.909908             0.904131
# 14     14            0.460139              0.911289             0.902876
# 15     15            0.467148              0.914073             0.899587
# 16     16            0.469607              0.915023             0.898509
# 17     17            0.475213              0.917189             0.895468
# 18     18            0.479450              0.918758             0.893671
# 19     19            0.482783              0.920054             0.891195
# 20     20            0.488302              0.921891             0.890118
# 21     21            0.488485              0.921991             0.889675
# 22     22            0.494665              0.924213             0.886008
# 23     23            0.497229              0.925093             0.884738
# 24     24            0.501212              0.926401             0.883264
# 25     25            0.506014              0.928136             0.879168
# 26     26            0.506463              0.928297             0.878700
# 27     27            0.511512              0.929916             0.876413
# 28     28            0.516390              0.931514             0.873388
# 29     29            0.523406              0.933749             0.868923
#
#                                                 model        f1
# 0   Single Input with 2 Dense Layers 512 Neurons a...  0.477288
# 1   Single Input with 2 Dense Layers 512 Neurons a...  0.508484
# 2   Single Input with 2 Dense Layers 512 Neurons a...  0.520722
# 3   Single Input with 2 Dense Layers 512 Neurons a...  0.529760
# 4   Single Input with 2 Dense Layers 512 Neurons a...  0.535318
# 5   Single Input with 2 Dense Layers 512 Neurons a...  0.541332
# 6   Single Input with 2 Dense Layers 512 Neurons a...  0.545851
# 7   Single Input with 2 Dense Layers 512 Neurons a...  0.548850
# 8   Single Input with 2 Dense Layers 512 Neurons a...  0.552666
# 9   Single Input with 2 Dense Layers 512 Neurons a...  0.557988
# 10  Single Input with 2 Dense Layers 512 Neurons a...  0.559752
# 11  Single Input with 2 Dense Layers 512 Neurons a...  0.563115
# 12  Single Input with 2 Dense Layers 512 Neurons a...  0.565389
# 13  Single Input with 2 Dense Layers 512 Neurons a...  0.569363
# 14  Single Input with 2 Dense Layers 512 Neurons a...  0.569743
# 15  Single Input with 2 Dense Layers 512 Neurons a...  0.575348
# 16  Single Input with 2 Dense Layers 512 Neurons a...  0.577336
# 17  Single Input with 2 Dense Layers 512 Neurons a...  0.578569
# 18  Single Input with 2 Dense Layers 512 Neurons a...  0.579198
# 19  Single Input with 2 Dense Layers 512 Neurons a...  0.583784
# 0   Single Input with 2 Dense Layers 1024 Neurons ...  0.486976
# 1   Single Input with 2 Dense Layers 1024 Neurons ...  0.506985
# 2   Single Input with 2 Dense Layers 1024 Neurons ...  0.515061
# 3   Single Input with 2 Dense Layers 1024 Neurons ...  0.522208
# 4   Single Input with 2 Dense Layers 1024 Neurons ...  0.527507
# 5   Single Input with 2 Dense Layers 1024 Neurons ...  0.530808
# 6   Single Input with 2 Dense Layers 1024 Neurons ...  0.535303
# 7   Single Input with 2 Dense Layers 1024 Neurons ...  0.538037
# 8   Single Input with 2 Dense Layers 1024 Neurons ...  0.540071
# 9   Single Input with 2 Dense Layers 1024 Neurons ...  0.544920
# ..                                                ...       ...
# 0   Multiple Input with 2 Dense Layers 1024 Neuron...  0.513995
# 1   Multiple Input with 2 Dense Layers 1024 Neuron...  0.537457
# 2   Multiple Input with 2 Dense Layers 1024 Neuron...  0.551145
# 3   Multiple Input with 2 Dense Layers 1024 Neuron...  0.558306
# 4   Multiple Input with 2 Dense Layers 1024 Neuron...  0.568834
# 5   Multiple Input with 2 Dense Layers 1024 Neuron...  0.572437
# 6   Multiple Input with 2 Dense Layers 1024 Neuron...  0.579698
# 7   Multiple Input with 2 Dense Layers 1024 Neuron...  0.582197
# 8   Multiple Input with 2 Dense Layers 1024 Neuron...  0.589076
# 9   Multiple Input with 2 Dense Layers 1024 Neuron...  0.592905
# 10  Multiple Input with 2 Dense Layers 1024 Neuron...  0.597202
# 11  Multiple Input with 2 Dense Layers 1024 Neuron...  0.599836
# 12  Multiple Input with 2 Dense Layers 1024 Neuron...  0.602846
# 13  Multiple Input with 2 Dense Layers 1024 Neuron...  0.606806
# 14  Multiple Input with 2 Dense Layers 1024 Neuron...  0.609602
# 15  Multiple Input with 2 Dense Layers 1024 Neuron...  0.614955
# 16  Multiple Input with 2 Dense Layers 1024 Neuron...  0.616828
# 17  Multiple Input with 2 Dense Layers 1024 Neuron...  0.620914
# 18  Multiple Input with 2 Dense Layers 1024 Neuron...  0.624083
# 19  Multiple Input with 2 Dense Layers 1024 Neuron...  0.626290
# 20  Multiple Input with 2 Dense Layers 1024 Neuron...  0.630644
# 21  Multiple Input with 2 Dense Layers 1024 Neuron...  0.630686
# 22  Multiple Input with 2 Dense Layers 1024 Neuron...  0.634875
# 23  Multiple Input with 2 Dense Layers 1024 Neuron...  0.636654
# 24  Multiple Input with 2 Dense Layers 1024 Neuron...  0.639524
# 25  Multiple Input with 2 Dense Layers 1024 Neuron...  0.642329
# 26  Multiple Input with 2 Dense Layers 1024 Neuron...  0.642565
# 27  Multiple Input with 2 Dense Layers 1024 Neuron...  0.645995
# 28  Multiple Input with 2 Dense Layers 1024 Neuron...  0.649037
# 29  Multiple Input with 2 Dense Layers 1024 Neuron...  0.653294
#
# [70 rows x 6 columns]

# %%
#Only the best model
best = all_models[all_models.model == all_models.model.unique()[2]]

fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(x='epoch', 
                y="f1", 
                hue="model",
                lw=5,
                data=best, 
                ax=ax)
plt.legend(loc='lower right')
ax.set_xlim((-1,30))
font_title={'size':30}
plt.title("F1 score", font_title)
font_axes={'size':20}
ax.set_xlabel("Epochs", font_axes)
ax.set_ylabel("F1", font_axes)
ax.set_xlim(xlims)
ax.set_ylim(ylims)
plt.legend(loc='lower right', prop={'size': 20})

# %%
best
# Out:
#     epoch  val_precision_on_1  val_accuracy_on_zero  val_accuracy_on_one  \
# 0       0            0.362379              0.869861             0.883744
# 1       1            0.383355              0.878988             0.898732
# 2       2            0.396103              0.884420             0.905624
# 3       3            0.402790              0.887114             0.909435
# 4       4            0.413943              0.892257             0.908950
# 5       5            0.417320              0.893487             0.911088
# 6       6            0.425316              0.897038             0.910020
# 7       7            0.427804              0.897977             0.910960
# 8       8            0.435686              0.901388             0.909157
# 9       9            0.440090              0.903234             0.908300
# 10     10            0.445438              0.905572             0.905823
# 11     11            0.448364              0.906673             0.905867
# 12     12            0.451686              0.907897             0.906068
# 13     13            0.456639              0.909908             0.904131
# 14     14            0.460139              0.911289             0.902876
# 15     15            0.467148              0.914073             0.899587
# 16     16            0.469607              0.915023             0.898509
# 17     17            0.475213              0.917189             0.895468
# 18     18            0.479450              0.918758             0.893671
# 19     19            0.482783              0.920054             0.891195
# 20     20            0.488302              0.921891             0.890118
# 21     21            0.488485              0.921991             0.889675
# 22     22            0.494665              0.924213             0.886008
# 23     23            0.497229              0.925093             0.884738
# 24     24            0.501212              0.926401             0.883264
# 25     25            0.506014              0.928136             0.879168
# 26     26            0.506463              0.928297             0.878700
# 27     27            0.511512              0.929916             0.876413
# 28     28            0.516390              0.931514             0.873388
# 29     29            0.523406              0.933749             0.868923
#
#                                                 model        f1
# 0   Multiple Input with 2 Dense Layers 1024 Neuron...  0.513995
# 1   Multiple Input with 2 Dense Layers 1024 Neuron...  0.537457
# 2   Multiple Input with 2 Dense Layers 1024 Neuron...  0.551145
# 3   Multiple Input with 2 Dense Layers 1024 Neuron...  0.558306
# 4   Multiple Input with 2 Dense Layers 1024 Neuron...  0.568834
# 5   Multiple Input with 2 Dense Layers 1024 Neuron...  0.572437
# 6   Multiple Input with 2 Dense Layers 1024 Neuron...  0.579698
# 7   Multiple Input with 2 Dense Layers 1024 Neuron...  0.582197
# 8   Multiple Input with 2 Dense Layers 1024 Neuron...  0.589076
# 9   Multiple Input with 2 Dense Layers 1024 Neuron...  0.592905
# 10  Multiple Input with 2 Dense Layers 1024 Neuron...  0.597202
# 11  Multiple Input with 2 Dense Layers 1024 Neuron...  0.599836
# 12  Multiple Input with 2 Dense Layers 1024 Neuron...  0.602846
# 13  Multiple Input with 2 Dense Layers 1024 Neuron...  0.606806
# 14  Multiple Input with 2 Dense Layers 1024 Neuron...  0.609602
# 15  Multiple Input with 2 Dense Layers 1024 Neuron...  0.614955
# 16  Multiple Input with 2 Dense Layers 1024 Neuron...  0.616828
# 17  Multiple Input with 2 Dense Layers 1024 Neuron...  0.620914
# 18  Multiple Input with 2 Dense Layers 1024 Neuron...  0.624083
# 19  Multiple Input with 2 Dense Layers 1024 Neuron...  0.626290
# 20  Multiple Input with 2 Dense Layers 1024 Neuron...  0.630644
# 21  Multiple Input with 2 Dense Layers 1024 Neuron...  0.630686
# 22  Multiple Input with 2 Dense Layers 1024 Neuron...  0.634875
# 23  Multiple Input with 2 Dense Layers 1024 Neuron...  0.636654
# 24  Multiple Input with 2 Dense Layers 1024 Neuron...  0.639524
# 25  Multiple Input with 2 Dense Layers 1024 Neuron...  0.642329
# 26  Multiple Input with 2 Dense Layers 1024 Neuron...  0.642565
# 27  Multiple Input with 2 Dense Layers 1024 Neuron...  0.645995
# 28  Multiple Input with 2 Dense Layers 1024 Neuron...  0.649037
# 29  Multiple Input with 2 Dense Layers 1024 Neuron...  0.653294
