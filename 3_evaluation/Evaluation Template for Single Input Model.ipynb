# %%
# Import

# General
import os
import pandas as pd
import numpy as np
import pickle
from collections import Counter
import sys
import copy

# Import helper functions
from evaluation_helper import *

# Add our pipeline folder to the path to import functions
sys.path.insert(1, '../2_modeling')
from model_helper import *

#Plotting
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import matplotlib.image as mpimg
# %matplotlib inline

# Data Processing
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import roc_curve, auc

# Machine Learning
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras import backend as K

# %% [markdown]
# # List the files of saved models

# %%
# Paths
models_path = '../../efs/models'
checkpoint_path='../../efs/models/Checkpoints/'
training_history_path='../../efs/models/Training_history/'
saved_models_path='../../efs/models/Saved_models/'

# %%
# os.listdir(checkpoint_path)

# %%
# os.listdir(training_history_path)

# %% [markdown]
# # Set the parameter

# %%
weights='model_no_cache_test_sample_size_all_epoch_20_dense_2_neurons_512_losswbc__num_open_layers_2_penalty_weight_10'

csv = '../1_cleaning/metadata_cleaned2.csv'

number_of_images = 'all'

history=weights+'.pickle'

# %%
# Create train-test dataset
#name_of_model='model1_sample_sizeall_epoch50_dense2_losswbc'
# Test train split, plus the features that are used to binarize the data
X_train, X_val, y_train_bin, y_val_bin, features = train_test_split_custom(number_of_images, csv)

# %% [markdown]
# # Load the model

# %% [markdown]
# ## Option 1 : load the saved model:

# %%
# Load the model
new_model = tf.keras.models.load_model('../../efs/models/Saved_models/' + weights + '.h5', \
                                       custom_objects={'weighted_bce': weighted_bce, 
                                                       'accuracy_on_zero': accuracy_on_zero,
                                                       'accuracy_on_one': accuracy_on_one, 
                                                       'precision_on_1': precision_on_1})

# %% [markdown]
# ## Option 2:  load the architecture + weights

# %%
# Architecture
vgg = VGG19(include_top=False, weights='imagenet', input_shape=(224,224,3))

transfer_layer = vgg.get_layer('block5_pool')

# cutting of the end of the model before the dense layers
conv_model = Model(inputs=vgg.input,
                   outputs=transfer_layer.output)

# freeze VGG
conv_model.trainable = False

num_label = y_train_bin.shape[1]

def create_model():
    # Start a new Keras Sequential model.
    model = Sequential()

    # Add the convolutional part of the VGG16 model from above.
    model.add(conv_model)

    # Flatten the output of the VGG16 model because it is from a
    # convolutional layer.
    model.add(Flatten())

    # Add a dense (aka. fully-connected) layer.
    # This is for combining features that the VGG16 model has
    # recognized in the image.
    model.add(Dense(1024, activation='relu'))

    model.add(Dropout(0.2))
    
    model.add(Dense(1024, activation='relu'))

    model.add(Dropout(0.2))

    model.add(Dense(num_label, activation='sigmoid'))
    
    # Settings
    LR = 1e-5
    optimizer = Adam(lr=LR)
    loss = weighted_bce
    metrics = [accuracy_on_one, accuracy_on_zero]
    
    model.compile(optimizer=optimizer, 
                  loss=loss, 
                  metrics=metrics)
    
    return model


new_model=create_model()

# %%
# Checkpoint path
# For weights to be saved each epoch
#checkpoint_path = '../../efs/models/Checkpoints/' + weights + '.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

# Loads the weights from the checkpoint path above
new_model.load_weights(checkpoint_path+weights+'.ckpt')

# %% [markdown]
# # Model architecture

# %%
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Model)                (None, 7, 7, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 184)               94392
# =================================================================
# Total params: 33,227,000
# Trainable params: 17,922,232
# Non-trainable params: 15,304,768
# _________________________________________________________________

# %% [markdown]
# # Predictions for the test dataset

# %%
# Create the datasets
# new_model.load_weights(checkpoint_path)
train_ds = create_dataset(X_train, y_train_bin)
val_ds = create_dataset(X_val, y_val_bin)

# %%
# Make the predictions
#%%time
# Takes 2:30 with 1000 images, 
# grab the predictions from the valadation ds
# predictions_test = new_model.predict(val_ds)
#predictions_train = new_model.predict(train_ds)

# SAVE the prediction
#pickle.dump(predictions_test, open( "predictions.p", "wb" ) )

# %%
# Optional step - load the predictions from file
#pickle.dump(predictions_test, open( "predictions.p", "wb" ) )
# Load the prediction
predictions_test= pickle.load( open( "predictions.p", "rb" ) )[0]

# %% [markdown]
# # Evaluations

# %% [markdown]
# ## Loss plots

# %%
# Load the training history
history=pickle.load(open(training_history_path+history, "rb" ))

# %%
# Plot the training history
plot_training_history_loss(history)

# %% [markdown]
# ## Model prediction on features that are present in photo

# %%
len(features)
# Out:
# 184

# %%
# Plot the predictions on 1s + the differences of medians 
plot_per_feature_error(predictions_test, y_val_bin, features)
# Out:
# (<Figure size 1584x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f5eb829f2e8>)

# %%
only_ones = np.array([np.where(y_true == 1, pred, np.nan) for y_true, pred in zip(y_val_bin,
                                                                              predictions_test)])
pred_df = pd.DataFrame(only_ones)

# Name the classes 
pred_df.columns = features

# order the whole dataframe and return the column names
order = pred_df.median().sort_values()

# %% [markdown]
# ## Recall on 1, recall on 0

# %%
plot_training_history_recall_on_one(history)
plot_training_history_recall_on_zero(history)

# %% [markdown]
# # Precision

# %%
plot_training_history_precision_on_one(history)

# %% [markdown]
# ## Precision - Recall curve with F1

# %%
precision_recall_f1(y_val_bin, predictions_test, features)

# %% [markdown]
# ## Make a prediction for an image

# %%
doPrediction(0, features, X_val, y_val_bin, predictions_test)

# %%
doPrediction(1,features, X_val, y_val_bin, predictions_test)

# %%
doPrediction(3,features, X_val, y_val_bin, predictions_test)

# %%
doPrediction(4,features, X_val, y_val_bin, predictions_test)

# %% [markdown]
# ## ROC AUC curve

# %%
grouped_roc(y_val_bin, predictions_test)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/metrics/ranking.py:659: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f5eb1b6dac8>)

# %%
# Plot 3 ROC curves for 3 features
n_classes = y_val_bin.shape[1]

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

    
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], predictions_test[:, i], pos_label=1)
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure()
for i in range(3):
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# %%
# ROC AUC scores per feature
for i in range(119):
    fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], predictions_test[:, i], pos_label=1)
    roc_auc[i] = auc(fpr[i], tpr[i])
    
roc_auc
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/sklearn/metrics/ranking.py:659: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# {0: 0.9957340508152432,
#  1: 0.9928496508735654,
#  2: 0.9447238387364374,
#  3: 0.9915518471317158,
#  4: 0.9578879248028951,
#  5: 0.9969690808979246,
#  6: 0.7752374067873993,
#  7: 0.9661675424387288,
#  8: 0.9879121632144526,
#  9: 0.8528017778780858,
#  10: 0.9579352747564867,
#  11: 0.9902697051503154,
#  12: 0.9922727406997633,
#  13: 0.987149308787534,
#  14: 0.9636344022035116,
#  15: 0.9919107088464384,
#  16: 0.9893501131643744,
#  17: 0.9697833775319279,
#  18: 0.9326915245402271,
#  19: 0.9441695105925203,
#  20: 0.8820081290997628,
#  21: 0.7994406836922384,
#  22: 0.9828800270396222,
#  23: 0.9748495652541537,
#  24: 0.9221700791609606,
#  25: 0.9835632583893646,
#  26: 0.8387204986878869,
#  27: 0.9654004706287419,
#  28: 0.9293710660316256,
#  29: 0.9775620299744556,
#  30: 0.933419870313074,
#  31: 0.981993474921208,
#  32: 0.9756150370040663,
#  33: 0.936867413537006,
#  34: 0.8533383863695039,
#  35: 0.780426652419478,
#  36: 0.8503538415005532,
#  37: 0.9210371584264143,
#  38: 0.8428547594491294,
#  39: 0.8681180830002048,
#  40: 0.8607414770819942,
#  41: 0.9963173253874926,
#  42: 0.8415638603914883,
#  43: 0.8075740572607978,
#  44: 0.8082541477724471,
#  45: 0.9859405542692049,
#  46: 0.9776544108249937,
#  47: 0.8809695379823872,
#  48: 0.9876082670803439,
#  49: 0.9991100905586603,
#  50: 0.9962505390067228,
#  51: 0.989062597056987,
#  52: 0.9901994893129479,
#  53: 0.9551356589147285,
#  54: 0.9831162469886141,
#  55: 0.9295970901258784,
#  56: 0.9515194712236685,
#  57: 0.9339667727979566,
#  58: 0.7655304651692536,
#  59: 0.8453556504890631,
#  60: nan,
#  61: 0.9789260536973151,
#  62: 0.993322965336033,
#  63: 0.9890211732847771,
#  64: 0.9939825753472016,
#  65: 0.9678996105882899,
#  66: 0.9735318664712304,
#  67: 0.9623911859534833,
#  68: 0.9697492964952673,
#  69: 0.967424341985689,
#  70: 0.9656721985869968,
#  71: 0.9516875198331747,
#  72: 0.9232590472086271,
#  73: 0.9872092822676886,
#  74: 0.9916620702679919,
#  75: 0.9854031356132196,
#  76: 0.988651520123288,
#  77: 0.9925824157911437,
#  78: 0.9789191799248116,
#  79: 0.9354692073810372,
#  80: 0.8717330501410816,
#  81: 0.9227219461587998,
#  82: 0.854943967357169,
#  83: 0.8852307379757278,
#  84: 0.9569389163084434,
#  85: 0.9434608308732297,
#  86: 0.958399680124187,
#  87: 0.8462332867897792,
#  88: 0.9386415281313537,
#  89: 0.8442582842524837,
#  90: 0.7968890623409237,
#  91: 0.9371398008014097,
#  92: 0.9098619243250886,
#  93: 0.8965191301484309,
#  94: 0.9605354976676714,
#  95: 0.8627734289955701,
#  96: 0.9491761448464942,
#  97: 0.9479514687196074,
#  98: 0.9227957015272163,
#  99: 0.9378697154288226,
#  100: 0.9393297144756252,
#  101: 0.9913881619714342,
#  102: 0.9987582319875823,
#  103: 0.9845136248415716,
#  104: 0.9778478218643499,
#  105: 0.9711017459361829,
#  106: 0.9922199763136946,
#  107: 0.990842440676728,
#  108: 0.9927521804055663,
#  109: 0.9912337174617482,
#  110: 0.8979010494752624,
#  111: 0.9913777282832201,
#  112: 0.9759878100042033,
#  113: 0.9925918723870041,
#  114: 0.9837450769781596,
#  115: 0.9742331648842402,
#  116: 0.9443477541422975,
#  117: 0.9412921376140428,
#  118: 0.975496715539346}

# %% [markdown]
# # Clustering
# Unsupervised clustering of the features by 3 dimensions: recall, precision, and relative feature occurrence.

# %%
recall_precision_frequency = create_recall_precision_frequency_df(predictions_test, y_val_bin, features)

# %% [markdown]
# # K means clustering on the features

# %%
cluster_elbow(recall_precision_frequency,cluster_mark=4)

# %% [markdown]
# # Choosing 4 clusters

# %%
recall_precision_frequency_labeled = cluster_features(recall_precision_frequency, num_clusters=4)

# %%
for feature in recall_precision_frequency.columns:
    recall_precision_frequency_labeled.boxplot(column=feature, by='labels', grid=False)
    plt.xlabel(feature)

# %% [markdown]
# # Heatmap of features

# %%
sortedDf = recall_precision_frequency_labeled.sort_values(by=['labels','recall'])
plt.figure(figsize=(20,30))
sns.heatmap(sortedDf.drop(labels=['labels'],axis=1), cmap='viridis', robust = True)
ax = plt.gca()
# ax.set_yticks([])

# %%
sortedDf.shape
# Out:
# (179, 4)

# %%
plt.style.use('seaborn')
# Plot by group
for group in range(4):
    temp = recall_precision_frequency_labeled[recall_precision_frequency.labels == group]
    temp[['recall','precision','frequency']].boxplot()
    plt.title('Group ' + str(group))
    plt.ylim((0, 1))
    plt.show()

# %% [markdown]
# # Create a 2d representation of feature groups

# %%
recall_precision_frequency_labeled['f1'] = f1_score(recall_precision_frequency_labeled,'recall','precision')

# %%
recall_precision_frequency_labeled.columns
# Out:
# Index(['recall', 'precision', 'frequency', 'labels', 'f1'], dtype='object')

# %%
# Set the points that you could use
things_to_keep = [
    'rosa',
    'bordeaux',
    'formschuhe-runderschuhspitze',
    'ausschnittkragenform-rundhalsausschnitt',
    'armellange-langarm',
    'sommer',
    'winter',
    'hosenlange-normalelange',
    'qualitaet-mischgewebemitelasthan',
    'qualitaet-kunstmischgewebe'
]

# %%
#Set the names of the groups
names_of_groups = ['low frequency, average recognition',
                  'low frequency, poor recognition',
                  'high frequency, excellent recognition',
                  'low frequency, excellent recognition']

recall_precision_frequency_labeled['Groups'] = recall_precision_frequency_labeled['labels'].map(dict(zip(range(4),names_of_groups)))

# %%
recall_precision_frequency_labeled[recall_precision_frequency_labeled['recall']>.5].shape[0]/recall_precision_frequency_labeled.shape[0]
# Out:
# 0.8715083798882681

# %%
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=(20, 15))
sns.scatterplot( 'frequency' ,'f1', hue='Groups', 
                palette=sns.color_palette("hls", 4), 
                data=recall_precision_frequency_labeled, 
                ax=ax,
                s=200)

# Moves the text to the right a little
epsilon=.007
fontsize=15
for i, txt in enumerate(recall_precision_frequency_labeled.index.to_list()):
    if txt in things_to_keep:
        ax.annotate(txt, 
                    (recall_precision_frequency_labeled.frequency[i]+epsilon, 
                     recall_precision_frequency_labeled.f1[i]),
                     fontsize=fontsize)
leg = plt.legend(loc='lower right', frameon=True, prop={'size': 25})
leg.get_frame().set_linewidth(1.0)
leg.get_frame().set_edgecolor('black')


font_axes={'size':30}
ax.set_xlabel("Frequency of feature in images", font_axes)
ax.set_ylabel("F1 score: Abiilty for the model to recognize the feature", font_axes)
# Out:
# Text(0, 0.5, 'F1 score: Abiilty for the model to recognize the feature')

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(20, 15))
sns.scatterplot( 'frequency' ,'recall', hue='Groups',
                data=recall_precision_frequency_labeled,
                s=200,
                ax=ax)

# Moves the text to the right a little
# epsilon=.007
# fontsize=26
# for i, txt in enumerate(recall_precision_frequency_labeled.index.to_list()):
#     if txt in things_to_keep:
#         ax.annotate(txt, 
#                     (recall_precision_frequency_labeled.frequency[i]+epsilon, 
#                      recall_precision_frequency_labeled.f1[i]),
#                      fontsize=fontsize)
leg = plt.legend(loc='lower right', frameon=True, prop={'size': 25})
leg.get_frame().set_linewidth(1.0)
leg.get_frame().set_edgecolor('black')
linestyle={'linestyle':'--', 'color':'red', 'lw':4}
ax.axhline(.8,0,1,**linestyle)


font_axes={'size':30}
ax.set_xlabel("Frequency of feature in images", font_axes)
ax.set_ylabel("Recall: Ability for the model to recognize the feature", font_axes)
# Out:
# Text(0, 0.5, 'Recall: Abiilty for the model to recognize the feature')

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(20, 15))
sns.scatterplot( 'frequency' ,'f1', hue='labels', 
                palette=sns.color_palette("muted",4), 
                data=recall_precision_frequency_labeled, 
                ax=ax,
                s=200)

# Moves the text to the right a little
epsilon=.007
fontsize=15
for i, txt in enumerate(recall_precision_frequency_labeled.index.to_list()):
    ax.annotate(txt, 
                (recall_precision_frequency_labeled.frequency[i]+epsilon, 
                 recall_precision_frequency_labeled.f1[i]),
                 fontsize=fontsize)

# %%
for i in recall_precision_frequency_labeled.Groups.unique():
    print('group', i)
    print(recall_precision_frequency_labeled[recall_precision_frequency_labeled.Groups==i].index)
# Out:
# group low frequency, poor recognition
# Index(['absatzart-blockabsatz', 'absatzart-flach', 'anlass-business',
#        'anlass-casual', 'anlass-freizeit',
#        'armabschluss-mitverstellbarenmanschetten', 'armellange-kurzarm',
#        'armellange-ohnearm', 'ausschnittkragenform-kapuzenkragen',
#        'ausschnittkragenform-polokragen',
#        'besonderheiten-abnehmbarerlaengenverstellbarerschulterriemen',
#        'besonderheiten-fransen', 'besonderheiten-goldfarbenedetails',
#        'bundhohe-normalebundhohe', 'decksohle-leder', 'falten-bugelfalten',
#        'formschuhe-offeneschuhspitze', 'formschuhe-runderschuhspitze',
#        'futtermaterial-L18', 'hosenbeinform-schmalzulaufendgeschnittenesbein',
#        'hosenlange-normalelange', 'innenausstattung-fachmitreissverschluss',
#        'innenausstattung-steckfacher',
#        'knopfleiste-mitaufgesetzterknopfleiste',
#        'knopfleiste-mitglatterknopfleiste',
#        'kragenstabchen-ohnekragenstabchen', 'laufsohle-gummi',
#        'musterung-aufdruck', 'musterung-streifenmuster',
#        'navabsatzhohe-bis3cmabsatzhohe', 'navabsatzhohe-uber6cmabsatzhohe',
#        'navdamentaschen-handtaschen', 'navpulloverstrick-pullover',
#        'rahmengenaht-False', 'rocklange-inmidirocklange',
#        'saison-leichtequalitaet', 'schuhhoehe-Sneakertief', 'slimfit',
#        'taschen-leistentaschen', 'taschen-schragertascheneingriff',
#        'verschlussartfashion-reisverschluss',
#        'verschlussschuhe-reissverschluss', 'verschlussschuhe-zumschlupfen',
#        'verschlussschuhe-zumschnuren', 'webart-ausjersey'],
#       dtype='object')
# group low frequency, medium recognition
# Index(['anlass-abend', 'armabschluss-manschettenmiteinemknopf',
#        'armellange-34armlange', 'ausschnittkragenform-blusenkragen',
#        'ausschnittkragenform-stehkragen', 'ausschnittkragenform-vausschnitt',
#        'beidesaison', 'besonderheiten-anhaenger',
#        'besonderheiten-mitschoenerraffung', 'besonderheiten-mitunterkleid',
#        'besonderheiten-silberfarbenedetails',
#        'besonderheiten-taschenbodenmitschutzfuesschen',
#        'besonderheiten-verstellbarerschulterriemen', 'bleichen-2',
#        'brusttasche-mitbrusttasche', 'buegeln-0', 'buegeln-2',
#        'chemReinigen-3', 'decksohle-textil', 'formschuhe-spitzeschuhspitze',
#        'futtermaterial-PES', 'futtermaterial-textil', 'griff-festergriff',
#        'griff-fliessend', 'hosenlange-78lange', 'innenausstattung-facher',
#        'innenausstattung-handyfach', 'innenausstattung-innentasche',
#        'innenausstattung-schluesselanhaenger', 'innenausstattung-vollfutter',
#        'klein gemustert', 'kragenstabchen-herausnehmbarekragenstabchen',
#        'laufsohle-leder', 'material-CAC', 'material-CV', 'material-EL',
#        'material-L1', 'material-L18', 'material-L2', 'material-PA',
#        'material-PES', 'material-PU', 'material-SE', 'material-WO',
#        'musterung-grafischemmuster', 'musterung-karomuster',
#        'musterung-organischemmuster', 'nassReinigen-0',
#        'navabsatzhohe-von3cm6cmabsatzhohe', 'navblusentuniken-blusen',
#        'navdamenaccessoires-schalsundtucher',
#        'navdamenschuhe-sandalensandaletten', 'navdamenschuhe-sneakers',
#        'navdamentaschen-umhangeschultertaschen', 'navhosen-chinos',
#        'navkleider-freizeitkleider', 'navpulloverstrick-strickjacken',
#        'navshirtstopssweats-shirts', 'navshirtstopssweats-sweatjs',
#        'passform-002', 'passform-003', 'passform-009', 'qualitaet-100cashmere',
#        'qualitaet-100seide', 'qualitaet-kunstleder',
#        'qualitaet-kunstmischgewebe', 'qualitaet-mischgewebemitelasthan',
#        'qualitaet-naturfasermischgewebe', 'qualitaet-naturfasermitelasthan',
#        'regularfit', 'saison-Warmequalitaet', 'tailliert',
#        'taschen-passepoiltaschen', 'trocknen-1',
#        'verschlussartfashion-druckknopfe', 'verschlussartfashion-knopfe',
#        'verschlussartfashion-magnetverschluss',
#        'verschlussartfashion-riegelverschluss',
#        'verschlussartfashion-schnurung', 'waschen-0', 'waschen-1', 'waschen-2',
#        'waschen-4', 'webart-Strukturstrick', 'webart-feineschiffongewebe',
#        'webart-gewebemitflacheroptik',
#        'webart-oxfordgewebestrukturierteroptik',
#        'webart-popelinegewebeflacheroptik', 'webart-strick',
#        'webart-twillgewebeleichterschragverlaufenderstruktur'],
#       dtype='object')
# group low frequency, excellent recognition
# Index(['anthrazit', 'armelform-raglanarmel', 'beige',
#        'besonderheiten-applikationen', 'besonderheiten-glitzerapplikationen',
#        'bordeaux', 'braun', 'ecru', 'grün', 'hellblau', 'material-CMD',
#        'material-LI', 'material-MER', 'navblusentuniken-schlupfblusen',
#        'navdamenschuhe-stiefelstiefeletten', 'navhosen-stoffhosen', 'offwhite',
#        'pink', 'qualitaet-100leinen', 'qualitaet-100wolle', 'rosa',
#        'trocknen-2', 'waschen-3', 'waschen-G',
#        'webart-chambraygewebeleichtstrukturierteroptik'],
#       dtype='object')
# group high frequency, excellent recognition
# Index(['armellange-langarm', 'ausschnittkragenform-rundhalsausschnitt',
#        'bleichen-0', 'buegeln-1', 'chemReinigen-0', 'chemReinigen-4',
#        'griff-weichergriff', 'material-CO', 'musterung-unifarben',
#        'navmusterung-gemustertodermitdruck', 'navmusterung-unifarben',
#        'passform-001', 'qualitaet-100baumwolle', 'qualitaet-echtesleder',
#        'saison-mittelschwerequalitaet', 'sommer', 'trocknen-0', 'waschen-F',
#        'winter'],
#       dtype='object')

# %%
recall_precision_frequency_labeled.sort_values(by='frequency',axis=0)
# Out:
#                                                recall  precision  frequency  \
# navdamenschuhe-stiefelstiefeletten           0.285714   0.400000   0.003042
# navblusentuniken-schlupfblusen               0.037037   0.166667   0.005986
# navhosen-stoffhosen                          0.333333   0.134615   0.006035
# navdamenschuhe-sandalensandaletten           0.848485   0.222222   0.007753
# navpulloverstrick-strickjacken               0.541667   0.433333   0.011580
# navkleider-freizeitkleider                   0.731343   0.178182   0.015015
# besonderheiten-mitunterkleid                 0.635294   0.210117   0.017615
# navdamenschuhe-sneakers                      0.942857   0.362637   0.019774
# navblusentuniken-blusen                      0.662791   0.351852   0.021050
# tailliert                                    0.921348   0.244776   0.023111
# formschuhe-offeneschuhspitze                 0.989899   0.556818   0.023749
# trocknen-2                                   0.326316   0.130802   0.024092
# pink                                         0.153846   0.208955   0.024289
# qualitaet-100leinen                          0.233333   0.190909   0.024534
# anthrazit                                    0.010000   0.090909   0.024681
# besonderheiten-applikationen                 0.406593   0.122112   0.024828
# navhosen-chinos                              0.948454   0.322807   0.025221
# ausschnittkragenform-kapuzenkragen           0.780952   0.694915   0.025270
# ecru                                         0.194690   0.146667   0.026104
# navabsatzhohe-uber6cmabsatzhohe              0.990099   0.558659   0.026153
# formschuhe-spitzeschuhspitze                 0.924731   0.238227   0.026300
# verschlussschuhe-reissverschluss             0.932692   0.436937   0.026349
# verschlussartfashion-schnurung               0.570093   0.241107   0.026595
# bordeaux                                     0.058333   0.107692   0.026889
# decksohle-textil                             0.888889   0.228571   0.026938
# innenausstattung-schluesselanhaenger         0.807339   0.179592   0.026987
# verschlussartfashion-riegelverschluss        0.887850   0.312500   0.027085
# navabsatzhohe-von3cm6cmabsatzhohe            0.947917   0.210162   0.027723
# laufsohle-leder                              0.903226   0.220039   0.028018
# kragenstabchen-herausnehmbarekragenstabchen  0.949580   0.299735   0.028165
# ...                                               ...        ...        ...
# passform-002                                 0.936387   0.307564   0.199117
# material-EL                                  0.869461   0.295002   0.206624
# chemReinigen-3                               0.940605   0.246254   0.225368
# waschen-1                                    0.923077   0.301676   0.239941
# webart-ausjersey                             0.966395   0.361799   0.240088
# saison-leichtequalitaet                      0.961026   0.509239   0.240481
# armellange-kurzarm                           0.989765   0.649429   0.240530
# anlass-casual                                0.952565   0.510373   0.247939
# buegeln-2                                    0.942959   0.289625   0.275515
# verschlussartfashion-reisverschluss          0.973835   0.532648   0.296565
# qualitaet-kunstmischgewebe                   0.893455   0.318848   0.311237
# qualitaet-echtesleder                        0.996649   0.710463   0.359470
# chemReinigen-0                               0.992834   0.341321   0.388665
# qualitaet-100baumwolle                       0.954146   0.487171   0.391904
# saison-mittelschwerequalitaet                0.992280   0.543061   0.411973
# waschen-F                                    0.988430   0.436178   0.435427
# ausschnittkragenform-rundhalsausschnitt      0.990022   0.643372   0.440088
# griff-weichergriff                           0.997437   0.580203   0.487291
# chemReinigen-4                               0.996597   0.458716   0.499411
# armellange-langarm                           0.996720   0.799023   0.527674
# passform-001                                 0.996360   0.612416   0.535231
# navmusterung-gemustertodermitdruck           0.942662   0.642274   0.560795
# sommer                                       0.989776   0.432177   0.621688
# material-CO                                  0.981883   0.580578   0.629490
# winter                                       0.993331   0.458077   0.698822
# buegeln-1                                    0.999678   0.681958   0.767910
# musterung-unifarben                          0.993356   0.717355   0.858881
# navmusterung-unifarben                       0.993105   0.727636   0.862463
# trocknen-0                                   0.999736   0.830523   0.933366
# bleichen-0                                   0.999754   0.888938   1.000000
#
#                                              labels        f1
# navdamenschuhe-stiefelstiefeletten                3  0.333333
# navblusentuniken-schlupfblusen                    3  0.060606
# navhosen-stoffhosen                               3  0.191781
# navdamenschuhe-sandalensandaletten                0  0.352201
# navpulloverstrick-strickjacken                    0  0.481481
# navkleider-freizeitkleider                        0  0.286550
# besonderheiten-mitunterkleid                      0  0.315789
# navdamenschuhe-sneakers                           0  0.523810
# navblusentuniken-blusen                           0  0.459677
# tailliert                                         0  0.386792
# formschuhe-offeneschuhspitze                      1  0.712727
# trocknen-2                                        3  0.186747
# pink                                              3  0.177215
# qualitaet-100leinen                               3  0.210000
# anthrazit                                         3  0.018018
# besonderheiten-applikationen                      3  0.187817
# navhosen-chinos                                   0  0.481675
# ausschnittkragenform-kapuzenkragen                1  0.735426
# ecru                                              3  0.167300
# navabsatzhohe-uber6cmabsatzhohe                   1  0.714286
# formschuhe-spitzeschuhspitze                      0  0.378855
# verschlussschuhe-reissverschluss                  1  0.595092
# verschlussartfashion-schnurung                    0  0.338889
# bordeaux                                          3  0.075676
# decksohle-textil                                  0  0.363636
# innenausstattung-schluesselanhaenger              0  0.293823
# verschlussartfashion-riegelverschluss             0  0.462287
# navabsatzhohe-von3cm6cmabsatzhohe                 0  0.344045
# laufsohle-leder                                   0  0.353870
# kragenstabchen-herausnehmbarekragenstabchen       0  0.455645
# ...                                             ...       ...
# passform-002                                      0  0.463039
# material-EL                                       0  0.440534
# chemReinigen-3                                    0  0.390320
# waschen-1                                         0  0.454737
# webart-ausjersey                                  1  0.526491
# saison-leichtequalitaet                           1  0.665719
# armellange-kurzarm                                1  0.784266
# anlass-casual                                     1  0.664640
# buegeln-2                                         0  0.443141
# verschlussartfashion-reisverschluss               1  0.688638
# qualitaet-kunstmischgewebe                        0  0.469976
# qualitaet-echtesleder                             2  0.829568
# chemReinigen-0                                    2  0.508000
# qualitaet-100baumwolle                            2  0.645011
# saison-mittelschwerequalitaet                     2  0.701953
# waschen-F                                         2  0.605263
# ausschnittkragenform-rundhalsausschnitt           2  0.779913
# griff-weichergriff                                2  0.733648
# chemReinigen-4                                    2  0.628256
# armellange-langarm                                2  0.886989
# passform-001                                      2  0.758573
# navmusterung-gemustertodermitdruck                2  0.764002
# sommer                                            2  0.601649
# material-CO                                       2  0.729694
# winter                                            2  0.627008
# buegeln-1                                         2  0.810804
# musterung-unifarben                               2  0.833091
# navmusterung-unifarben                            2  0.839893
# trocknen-0                                        2  0.907308
# bleichen-0                                        2  0.941095
#
# [179 rows x 5 columns]

# %%
for x in []:
    print(x)
